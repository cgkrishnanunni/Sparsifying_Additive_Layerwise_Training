# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from Utilities.get_image_data import load_data
from Utilities.form_train_val_test_batches import form_train_val_test_batches
from Utilities.NN_FC_layerwise import FCLayerwise
from Utilities.NN_FC_layerwise_new import FCLayerwise_new
from Utilities.Net import Final_Network
from Utilities.Net_new import Final_Network_ALGO_II
from Utilities.create_data import create_new
from Utilities.loss_and_accuracies import data_loss_classification, accuracy_classification
from Utilities.manifold_regularization import manifold_classification
from Utilities.manifold_regularization_new import manifold_classification_new
from Utilities.optimize_layerwise import optimize
from Utilities.additive_output import net_output 
from Utilities.plot_and_save_figures_layerwise import plot_fig
from joblib import Parallel, delayed
from Utilities.optimize_step_II import optimize_step
import multiprocessing
import random

# %%
from decimal import Decimal # for filenames

import pdb #Equivalent of keyboard in MATLAB, just add "pdb.set_trace()"

import os
import sys

# %%
###############################################################################
#                       HyperParameters and RunOptions                        #
###############################################################################
class Hyperparameters:
    max_hidden_layers = 5 # For this architecture, need at least 2. One for the mapping to the feature space, one as a trainable hidden layer. EXCLUDES MAPPING BACK TO DATA SPACE
    num_hidden_nodes  = 500 
    activation        = 'elu'
    classification_act= 'softmax'
    regularization    = 0.001
    manifold          = 0.003
    node_TOL          = 1e-4
    error_TOL         = 1e-4
    batch_size        = 1000
    num_epochs        = 100
    
    num_networks      = 6

# %%
class Hyperparameters_new:
    max_hidden_layers = 3 # For this architecture, need at least 2. One for the mapping to the feature space, one as a trainable hidden layer. EXCLUDES MAPPING BACK TO DATA SPACE
    num_hidden_nodes  = 20
    activation        = 'relu'
    classification_act= 'linear'
    regularization    = 0.000
    manifold          = 0.000
    node_TOL          = 1e-4
    error_TOL         = 1e-4
    batch_size        = 1000
    num_epochs        = 50

# %%
class RunOptions:
    def __init__(self):    
        #=== Choose Which GPU to Use ===#
        self.which_gpu = '1'
        
        #=== Use L_1 Regularization ===#
        self.use_L1 = 1
        
        #=== Choose Data Set ===#
        self.data_MNIST = 1
        self.data_CIFAR10 = 0 
        self.data_CIFAR100 = 0
        
        #=== Random Seed ===#
        self.random_seed = 1234

# %%
###############################################################################
#                                 File Paths                                  #
###############################################################################         
class FilePaths():    
    def __init__(self, hyperp, run_options):  
        #=== Declaring File Name Components ===# 
        self.NN_type = 'FC'
        if run_options.data_MNIST == 1:
            self.dataset = 'MNIST'
        if run_options.data_CIFAR10 == 1:
            self.dataset = 'CIFAR10'
        if run_options.data_CIFAR100 == 1:
            self.dataset = 'CIFAR100'
        if hyperp.regularization >= 1:
            hyperp.regularization = int(hyperp.regularization)
            regularization_string = str(hyperp.regularization)
        else:
            regularization_string = str(hyperp.regularization)
            regularization_string = 'pt' + regularization_string[2:]                        
        node_TOL_string = str('%.2e' %Decimal(hyperp.node_TOL))
        node_TOL_string = node_TOL_string[-1]
        error_TOL_string = str('%.2e' %Decimal(hyperp.error_TOL))
        error_TOL_string = error_TOL_string[-1]
        
        #=== File Name ===#
        if run_options.use_L1 == 0:
            self.filename = self.dataset + '_' + self.NN_type + '_mhl%d_hl%d_eTOL%s_b%d_e%d' %(hyperp.max_hidden_layers, hyperp.num_hidden_nodes, error_TOL_string, hyperp.batch_size, hyperp.num_epochs)
        else:
            self.filename = self.dataset + '_' + self.NN_type + '_L1_mhl%d_hl%d_r%s_nTOL%s_eTOL%s_b%d_e%d' %(hyperp.max_hidden_layers, hyperp.num_hidden_nodes, regularization_string, node_TOL_string, error_TOL_string, hyperp.batch_size, hyperp.num_epochs)

        #=== Saving Trained Neural Network and Tensorboard ===#
        #self.NN_savefile_directory = 'C:/Users/Chandradut/Desktop/Sparse training/Trained_NNs/' + self.filename # Since we need to save four different types of files to save a neural network model, we need to create a new folder for each model
        self.NN_savefile_directory =  self.filename
        self.NN_savefile_name = self.NN_savefile_directory + '/' + self.filename # The file path and name for the four files
        #self.tensorboard_directory = 'C:/Users/Chandradut/Desktop/Sparse training/Tensorboard/' + self.filename

###############################################################################

# %%
if __name__ == "__main__":     

    #=== Hyperparameters and Run Options ===#    
    hyperp = Hyperparameters()
    hyperp_new=Hyperparameters_new()
    run_options = RunOptions()
    

    #=== File Names ===#
    file_paths = FilePaths(hyperp, run_options)
    
    #=== Load Data ===#       
    data_train, labels_train,\
    data_test, labels_test,\
    data_input_shape, num_channels, label_dimensions\
    = load_data(file_paths.NN_type, file_paths.dataset, run_options.random_seed) 
    


    
    #for i in range(1,hyperp.num_networks):
    for i in range(6,7):
    #=== Initiate training ===#
        #trainer(hyperp, run_options, file_paths,i) 
        

    
            
        
        
        
        
            #=== GPU Settings ===#
        os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
        os.environ["CUDA_VISIBLE_DEVICES"] = run_options.which_gpu
    
            #=== Neural Network ===#
        if run_options.use_L1 == 0:
            kernel_regularizer = None
            bias_regularizer = None  
        else:
            kernel_regularizer = tf.keras.regularizers.l1(hyperp.regularization)
            bias_regularizer = tf.keras.regularizers.l1(hyperp.regularization)

        data_train,new_label,labels_train=create_new(data_train, labels_train,hyperp,hyperp_new, run_options, data_input_shape, label_dimensions,i)
        
        #=== Construct Validation Set and Batches ===# 
        #data_and_labels_train, data_and_labels_val, data_and_labels_test,\
        #num_data_train, num_data_val, num_data_test,\
        #num_batches_train, num_batches_val, num_batches_test,data_and_labels_train_new\
        #= form_train_val_test_batches(data_train, labels_train, \
                                  #data_test, labels_test, \
                                  #hyperp.batch_size, new_label, run_options.random_seed)
        
        
        if i==1:
            NN = FCLayerwise(hyperp, run_options, data_input_shape, label_dimensions,kernel_regularizer, bias_regularizer)    

    #                                 Training                                    #
###############################################################################

        if i==1:
            hyperp_n=hyperp
            optimize(hyperp,hyperp_n, run_options, file_paths, NN, data_loss_classification, accuracy_classification, data_and_labels_train, data_and_labels_val, data_and_labels_test, label_dimensions, num_batches_train,data_and_labels_train_new,manifold_classification,hyperp.batch_size,run_options.random_seed,num_data_train,i,data_input_shape)   
        
        if i>1:
            hyperp_n=Hyperparameters_new()
            optimize_step(data_train,new_label,data_test, labels_test,i,label_dimensions,hyperp,hyperp_new,run_options,data_input_shape,accuracy_classification,labels_train)
        
        
        if i==1:
            plot_fig(hyperp, run_options, file_paths,i)
            
       # if i>1:
           # plot_fig(hyperp_new, run_options, file_paths,i)
# Out:
# ListWrapper([784, 500, 500, 10])
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 500)               392500
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 648,010
# Trainable params: 648,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 67/67 [==============================] - 1s 5ms/step - loss: 0.1842 - mean_squared_error: 0.1842
# Epoch 2/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0496 - mean_squared_error: 0.0496
# Epoch 3/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0326 - mean_squared_error: 0.0326
# Epoch 4/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0243 - mean_squared_error: 0.0243
# Epoch 5/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0193 - mean_squared_error: 0.0193
# Epoch 6/200
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0159 - mean_squared_error: 0.0159
# Epoch 7/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 8/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 9/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0102 - mean_squared_error: 0.0102
# Epoch 10/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 11/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0080 - mean_squared_error: 0.0080
# Epoch 12/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 13/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 14/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 15/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 16/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 17/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 18/200
# 67/67 [==============================] - 0s 7ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 19/200
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 20/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 21/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0035 - mean_squared_error: 0.0035
# Epoch 22/200
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 23/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 24/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 25/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 26/200
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 27/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 28/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 29/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 30/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 31/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 32/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 33/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 34/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 35/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 36/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 37/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 38/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 39/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 40/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 41/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 42/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 43/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 44/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 45/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 46/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 47/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 48/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 49/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 50/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 51/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 52/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 53/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 54/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 55/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 56/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 57/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 58/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 59/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 60/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 61/200
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 62/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 63/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 64/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 65/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 66/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 67/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 68/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 69/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 70/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 71/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 72/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 73/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 74/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 75/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 76/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 77/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 78/200
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 79/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 80/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 81/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 82/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 83/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 84/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 85/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 86/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 87/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 88/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 89/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 90/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 91/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 92/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 93/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 94/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 95/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 96/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 97/200
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 98/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 99/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 100/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 101/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 102/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 103/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 104/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 105/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 106/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 107/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 108/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 109/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 110/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 111/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 112/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 113/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 114/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 115/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 116/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 117/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 118/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 119/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 120/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 121/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 122/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 123/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 124/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 125/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 126/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 127/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 128/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 129/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 130/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 131/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 132/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 133/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 134/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 135/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 136/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 137/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 138/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 139/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 140/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 141/200
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 142/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 143/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 144/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 145/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 146/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 147/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 148/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 149/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 150/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 151/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 152/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 153/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 154/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 155/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 156/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 157/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 158/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 159/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 160/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 161/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 162/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 163/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 164/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 165/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 166/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 167/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 168/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 169/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 170/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 171/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 172/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 173/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 174/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 175/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 176/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 177/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 178/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 179/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 180/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 181/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 182/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 183/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 184/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 185/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 186/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 187/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 188/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 189/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 190/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 191/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 192/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 193/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 194/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 195/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 196/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 197/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 198/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 199/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 200/200
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# ListWrapper([784, 500, 500, 10])
# Test Set:  Error: 0.986
#
# INFO:tensorflow:Assets written to: WEIGHTS/model6/assets
# Final Model Saved

# %%
if not os.path.exists("WEIGHTS"):
    os.makedirs("WEIGHTS")
model.save("WEIGHTS"+'/'+"model"+str(2))
print('Final Model Saved')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-cb34b2b614ed> in <module>
#       1 if not os.path.exists("WEIGHTS"):
#       2     os.makedirs("WEIGHTS")
# ----> 3 model.save("WEIGHTS"+'/'+"model"+str(2))
#       4 print('Final Model Saved')
#
# NameError: name 'model' is not defined

# %%
from tensorflow import keras
from tensorflow.keras import layers
    
data_train, labels_train,\
data_test, labels_test,\
data_input_shape, num_channels, label_dimensions\
= load_data(file_paths.NN_type, file_paths.dataset, run_options.random_seed)    
    
model = keras.Sequential()
model.add(layers.Dense(500, activation='elu', input_shape=(784,)))
model.add(layers.Dense(500, activation='elu'))
model.add(layers.Dense(500, activation='elu'))
model.add(layers.Dense(500, activation='elu'))
model.add(layers.Dense(10, activation='softmax'))
model.summary()
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss=loss_fn, optimizer=opt, metrics=[loss_fn])
model.fit(data_train,labels_train,batch_size=1000,epochs=100,verbose=1)
    
batch_pred_test = model(data_test)
mean_accuracy_test = tf.keras.metrics.Mean()
            
mean_accuracy_test(accuracy_classification(batch_pred_test, labels_test))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 500)               392500
# _________________________________________________________________
# dense_9 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_10 (Dense)             (None, 500)               250500
# _________________________________________________________________
# dense_11 (Dense)             (None, 500)               250500
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                5010
# =================================================================
# Total params: 1,149,010
# Trainable params: 1,149,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.6503 - sparse_categorical_crossentropy: 0.6503
# Epoch 2/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.2582 - sparse_categorical_crossentropy: 0.2582
# Epoch 3/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.1967 - sparse_categorical_crossentropy: 0.1967
# Epoch 4/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.1588 - sparse_categorical_crossentropy: 0.1588
# Epoch 5/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.1309 - sparse_categorical_crossentropy: 0.1309
# Epoch 6/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.1108 - sparse_categorical_crossentropy: 0.1108
# Epoch 7/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0956 - sparse_categorical_crossentropy: 0.0956
# Epoch 8/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0834 - sparse_categorical_crossentropy: 0.0834
# Epoch 9/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0734 - sparse_categorical_crossentropy: 0.0734
# Epoch 10/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0638 - sparse_categorical_crossentropy: 0.0638
# Epoch 11/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0576 - sparse_categorical_crossentropy: 0.0576
# Epoch 12/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0509 - sparse_categorical_crossentropy: 0.0509
# Epoch 13/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0454 - sparse_categorical_crossentropy: 0.0454
# Epoch 14/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0401 - sparse_categorical_crossentropy: 0.0401
# Epoch 15/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0365 - sparse_categorical_crossentropy: 0.0365
# Epoch 16/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0319 - sparse_categorical_crossentropy: 0.0319
# Epoch 17/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0288 - sparse_categorical_crossentropy: 0.0288
# Epoch 18/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0262 - sparse_categorical_crossentropy: 0.0262
# Epoch 19/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0231 - sparse_categorical_crossentropy: 0.0231
# Epoch 20/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0203 - sparse_categorical_crossentropy: 0.0203
# Epoch 21/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0184 - sparse_categorical_crossentropy: 0.0184
# Epoch 22/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0174 - sparse_categorical_crossentropy: 0.0174
# Epoch 23/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0142 - sparse_categorical_crossentropy: 0.0142
# Epoch 24/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0122 - sparse_categorical_crossentropy: 0.0122
# Epoch 25/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0117 - sparse_categorical_crossentropy: 0.0117
# Epoch 26/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0095 - sparse_categorical_crossentropy: 0.0095
# Epoch 27/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0089 - sparse_categorical_crossentropy: 0.0089
# Epoch 28/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0082 - sparse_categorical_crossentropy: 0.0082
# Epoch 29/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0072 - sparse_categorical_crossentropy: 0.0072
# Epoch 30/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0060 - sparse_categorical_crossentropy: 0.0060
# Epoch 31/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0053 - sparse_categorical_crossentropy: 0.0053
# Epoch 32/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0046 - sparse_categorical_crossentropy: 0.0046
# Epoch 33/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0038 - sparse_categorical_crossentropy: 0.0038
# Epoch 34/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0037 - sparse_categorical_crossentropy: 0.0037
# Epoch 35/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0030 - sparse_categorical_crossentropy: 0.0030
# Epoch 36/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0026 - sparse_categorical_crossentropy: 0.0026
# Epoch 37/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0023 - sparse_categorical_crossentropy: 0.0023
# Epoch 38/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0022 - sparse_categorical_crossentropy: 0.0022
# Epoch 39/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0019 - sparse_categorical_crossentropy: 0.0019
# Epoch 40/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0018 - sparse_categorical_crossentropy: 0.0018
# Epoch 41/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0015 - sparse_categorical_crossentropy: 0.0015
# Epoch 42/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0014 - sparse_categorical_crossentropy: 0.0014
# Epoch 43/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0013 - sparse_categorical_crossentropy: 0.0013
# Epoch 44/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0012 - sparse_categorical_crossentropy: 0.0012
# Epoch 45/100
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0011 - sparse_categorical_crossentropy: 0.0011
# Epoch 46/100
# 60/60 [==============================] - 1s 10ms/step - loss: 9.6931e-04 - sparse_categorical_crossentropy: 9.6931e-04
# Epoch 47/100
# 60/60 [==============================] - 1s 10ms/step - loss: 9.6390e-04 - sparse_categorical_crossentropy: 9.6390e-04
# Epoch 48/100
# 60/60 [==============================] - 1s 10ms/step - loss: 8.1482e-04 - sparse_categorical_crossentropy: 8.1482e-04
# Epoch 49/100
# 60/60 [==============================] - 1s 10ms/step - loss: 7.7154e-04 - sparse_categorical_crossentropy: 7.7154e-04
# Epoch 50/100
# 60/60 [==============================] - 1s 10ms/step - loss: 7.1736e-04 - sparse_categorical_crossentropy: 7.1736e-04
# Epoch 51/100
# 60/60 [==============================] - 1s 10ms/step - loss: 6.5745e-04 - sparse_categorical_crossentropy: 6.5745e-04
# Epoch 52/100
# 60/60 [==============================] - 1s 10ms/step - loss: 6.1375e-04 - sparse_categorical_crossentropy: 6.1375e-04
# Epoch 53/100
# 60/60 [==============================] - 1s 10ms/step - loss: 5.8860e-04 - sparse_categorical_crossentropy: 5.8860e-04
# Epoch 54/100
# 60/60 [==============================] - 1s 10ms/step - loss: 5.5712e-04 - sparse_categorical_crossentropy: 5.5712e-04
# Epoch 55/100
# 60/60 [==============================] - 1s 10ms/step - loss: 5.5143e-04 - sparse_categorical_crossentropy: 5.5143e-04
# Epoch 56/100
# 60/60 [==============================] - 1s 10ms/step - loss: 4.6665e-04 - sparse_categorical_crossentropy: 4.6665e-04
# Epoch 57/100
# 60/60 [==============================] - 1s 10ms/step - loss: 4.3993e-04 - sparse_categorical_crossentropy: 4.3993e-04
# Epoch 58/100
# 60/60 [==============================] - 1s 10ms/step - loss: 4.1748e-04 - sparse_categorical_crossentropy: 4.1748e-04
# Epoch 59/100
# 60/60 [==============================] - 1s 10ms/step - loss: 3.9160e-04 - sparse_categorical_crossentropy: 3.9160e-04
# Epoch 60/100
# 60/60 [==============================] - 1s 10ms/step - loss: 3.6858e-04 - sparse_categorical_crossentropy: 3.6858e-04
# Epoch 61/100
# 60/60 [==============================] - 1s 9ms/step - loss: 3.5317e-04 - sparse_categorical_crossentropy: 3.5317e-04
# Epoch 62/100
# 60/60 [==============================] - 1s 10ms/step - loss: 3.1760e-04 - sparse_categorical_crossentropy: 3.1760e-04
# Epoch 63/100
# 60/60 [==============================] - 1s 10ms/step - loss: 3.0694e-04 - sparse_categorical_crossentropy: 3.0694e-04
# Epoch 64/100
# 60/60 [==============================] - 1s 10ms/step - loss: 2.9077e-04 - sparse_categorical_crossentropy: 2.9077e-04
# Epoch 65/100
# 60/60 [==============================] - 1s 10ms/step - loss: 2.7509e-04 - sparse_categorical_crossentropy: 2.7509e-04
# Epoch 66/100
# 60/60 [==============================] - 1s 9ms/step - loss: 2.6011e-04 - sparse_categorical_crossentropy: 2.6011e-04
# Epoch 67/100
# 60/60 [==============================] - 1s 10ms/step - loss: 2.4802e-04 - sparse_categorical_crossentropy: 2.4802e-04
# Epoch 68/100
# 60/60 [==============================] - 1s 10ms/step - loss: 2.3248e-04 - sparse_categorical_crossentropy: 2.3248e-04
# Epoch 69/100
# 60/60 [==============================] - 1s 10ms/step - loss: 2.1754e-04 - sparse_categorical_crossentropy: 2.1754e-04
# Epoch 70/100
# 60/60 [==============================] - 1s 10ms/step - loss: 2.1664e-04 - sparse_categorical_crossentropy: 2.1664e-04
# Epoch 71/100
# 60/60 [==============================] - 1s 10ms/step - loss: 2.0052e-04 - sparse_categorical_crossentropy: 2.0052e-04
# Epoch 72/100
# 60/60 [==============================] - 1s 10ms/step - loss: 1.8789e-04 - sparse_categorical_crossentropy: 1.8789e-04
# Epoch 73/100
# 60/60 [==============================] - 1s 10ms/step - loss: 1.7846e-04 - sparse_categorical_crossentropy: 1.7846e-04
# Epoch 74/100
# 60/60 [==============================] - 1s 9ms/step - loss: 1.6895e-04 - sparse_categorical_crossentropy: 1.6895e-04
# Epoch 75/100
# 60/60 [==============================] - 1s 10ms/step - loss: 1.6334e-04 - sparse_categorical_crossentropy: 1.6334e-04
# Epoch 76/100
# 60/60 [==============================] - 1s 10ms/step - loss: 1.5401e-04 - sparse_categorical_crossentropy: 1.5401e-04
# Epoch 77/100
# 60/60 [==============================] - 1s 10ms/step - loss: 1.4705e-04 - sparse_categorical_crossentropy: 1.4705e-04
# Epoch 78/100
# 60/60 [==============================] - 1s 9ms/step - loss: 1.4098e-04 - sparse_categorical_crossentropy: 1.4098e-04
# Epoch 79/100
# 60/60 [==============================] - 1s 10ms/step - loss: 1.3494e-04 - sparse_categorical_crossentropy: 1.3494e-04
# Epoch 80/100
# 60/60 [==============================] - 1s 10ms/step - loss: 1.2634e-04 - sparse_categorical_crossentropy: 1.2634e-04
# Epoch 81/100
# 60/60 [==============================] - 1s 10ms/step - loss: 1.2030e-04 - sparse_categorical_crossentropy: 1.2030e-04
# Epoch 82/100
# 60/60 [==============================] - 1s 10ms/step - loss: 1.1487e-04 - sparse_categorical_crossentropy: 1.1487e-04
# Epoch 83/100
# 60/60 [==============================] - 1s 10ms/step - loss: 1.0884e-04 - sparse_categorical_crossentropy: 1.0884e-04
# Epoch 84/100
# 60/60 [==============================] - 1s 10ms/step - loss: 1.0339e-04 - sparse_categorical_crossentropy: 1.0339e-04
# Epoch 85/100
# 60/60 [==============================] - 1s 9ms/step - loss: 9.7684e-05 - sparse_categorical_crossentropy: 9.7684e-05
# Epoch 86/100
# 60/60 [==============================] - 1s 9ms/step - loss: 9.6251e-05 - sparse_categorical_crossentropy: 9.6251e-05
# Epoch 87/100
# 60/60 [==============================] - 1s 10ms/step - loss: 9.0055e-05 - sparse_categorical_crossentropy: 9.0055e-05
# Epoch 88/100
# 60/60 [==============================] - 1s 10ms/step - loss: 8.5489e-05 - sparse_categorical_crossentropy: 8.5489e-05
# Epoch 89/100
# 60/60 [==============================] - 1s 9ms/step - loss: 8.3659e-05 - sparse_categorical_crossentropy: 8.3659e-05
# Epoch 90/100
# 60/60 [==============================] - 1s 9ms/step - loss: 7.9905e-05 - sparse_categorical_crossentropy: 7.9905e-05
# Epoch 91/100
# 60/60 [==============================] - 1s 10ms/step - loss: 7.7621e-05 - sparse_categorical_crossentropy: 7.7621e-05
# Epoch 92/100
# 60/60 [==============================] - 1s 10ms/step - loss: 7.3578e-05 - sparse_categorical_crossentropy: 7.3578e-05
# Epoch 93/100
# 60/60 [==============================] - 1s 10ms/step - loss: 6.8388e-05 - sparse_categorical_crossentropy: 6.8388e-05
# Epoch 94/100
# 60/60 [==============================] - 1s 10ms/step - loss: 6.6758e-05 - sparse_categorical_crossentropy: 6.6758e-05
# Epoch 95/100
# 60/60 [==============================] - 1s 9ms/step - loss: 6.3233e-05 - sparse_categorical_crossentropy: 6.3233e-05
# Epoch 96/100
# 60/60 [==============================] - 1s 10ms/step - loss: 6.2621e-05 - sparse_categorical_crossentropy: 6.2621e-05
# Epoch 97/100
# 60/60 [==============================] - 1s 10ms/step - loss: 5.8516e-05 - sparse_categorical_crossentropy: 5.8516e-05
# Epoch 98/100
# 60/60 [==============================] - 1s 10ms/step - loss: 5.5502e-05 - sparse_categorical_crossentropy: 5.5502e-05
# Epoch 99/100
# 60/60 [==============================] - 1s 10ms/step - loss: 5.3050e-05 - sparse_categorical_crossentropy: 5.3050e-05
# Epoch 100/100
# 60/60 [==============================] - 1s 10ms/step - loss: 5.0830e-05 - sparse_categorical_crossentropy: 5.0830e-05
# <tf.Tensor: shape=(), dtype=float32, numpy=0.9804>

# %%
Network=Final_Network( hyperp,run_options, data_input_shape, label_dimensions) 
                #NNN._set_inputs( data)
            #Network.load_weights("WEIGHTS"+'/'+"model_weights"+str(j-1)+'.hdf5').expect_partial()
                #NNN.save("WEIGHTS"+'/'+"model"+str(i_net-1))
                #Network.load_weights("WEIGHTS"+'/'+"model_weights"+str(i_net-1)+'.hdf5').expect_partial()
                #Network=tf.keras.models.load_model("WEIGHTS"+'/'+"model"+str(i_net-1))
Network.load_weights("WEIGHTS"+'/'+"model_weights"+str(2-1)).expect_partial()

# %%
y=Network(data_test)

# %%
mean_accuracy_test = tf.keras.metrics.Mean()
mean_accuracy_test(accuracy_classification(y, labels_test))

# %%
        data_train,new_label,labels_train=create_new(data_train, labels_train,hyperp,hyperp_new, run_options, data_input_shape, label_dimensions,1)
        
        #=== Construct Validation Set and Batches ===# 
        data_and_labels_train, data_and_labels_val, data_and_labels_test,\
        num_data_train, num_data_val, num_data_test,\
        num_batches_train, num_batches_val, num_batches_test,data_and_labels_train_new\
        = form_train_val_test_batches(data_train, labels_train, \
                                  data_test, labels_test, \
                                  hyperp.batch_size, new_label, run_options.random_seed)

# %%
for batch_num_num, (batch_data_val, batch_labels_val,labels_val) in data_and_labels_val.enumerate():
    batch_data_val

# %%
new=batch_data_val

# %%
tf.norm(batch_data_val-new)

# %%
labels_train=np.squeeze(labels_train,axis=1)

# %%
Network=Final_Network(hyperp, run_options, data_input_shape, label_dimensions,
                      kernel_regularizer, bias_regularizer)

# %%
Network.load_weights("WEIGHTS"+'/'+"model_weights1")

# %%
(data_train, labels_train), (data_test, labels_test) = datasets.mnist.load_data()
data_train = data_train.reshape(data_train.shape[0], 28, 28, 1)
data_test = data_test.reshape(data_test.shape[0], 28, 28, 1)
label_dimensions = 10
data_input_shape = data_train.shape[1:]

#=== Casting as float32 ===#
data_train = tf.cast(data_train,tf.float32)
labels_train = tf.cast(labels_train, tf.int32)
data_test = tf.cast(data_test, tf.float32)
labels_test = tf.cast(labels_test, tf.int32)
    
#=== Normalize Data ===#
data_train, data_test = data_train/255.0, data_test/255.0
data_train = tf.image.per_image_standardization(data_train) # Linearly scales each image to have mean 0 and variance 1
data_test = tf.image.per_image_standardization(data_test)   # Linearly scales each image to have mean 0 and variance 1

data_train = tf.reshape(data_train, (len(data_train), 28*28))
data_test = tf.reshape(data_test, (len(data_test), 28*28))

num_data_train = len(data_train)
num_data_test = len(data_test)
random_seed=1234
batch_size        = 1000

data_and_labels_train_full = tf.data.Dataset.from_tensor_slices((data_train, labels_train)).shuffle(num_data_train, seed=random_seed)
data_and_labels_test = tf.data.Dataset.from_tensor_slices((data_test, labels_test)).batch(batch_size)
num_batches_test = len(list(data_and_labels_test))

#=== Partitioning Out Validation Set and Constructing Batches ===#
current_num_data_train = num_data_train
num_data_train = int(0.8 * num_data_train)
num_data_val = current_num_data_train - num_data_train
data_and_labels_train_full = tf.data.Dataset.from_tensor_slices((data_train, labels_train)).shuffle(num_data_train, seed=random_seed)
data_and_labels_train = data_and_labels_train_full.take(num_data_train).batch(batch_size)
data_and_labels_val = data_and_labels_train_full.skip(num_data_train).batch(batch_size)    
num_batches_train = len(list(data_and_labels_train))
num_batches_val = len(list(data_and_labels_val))

# %%
(data_train, labels_train), (data_test, labels_test) = datasets.mnist.load_data()
data_train = data_train.reshape(data_train.shape[0], 28, 28, 1)
data_test = data_test.reshape(data_test.shape[0], 28, 28, 1)
label_dimensions = 10
data_input_shape = data_train.shape[1:]

#=== Casting as float32 ===#
data_train = tf.cast(data_train,tf.float32)
labels_train = tf.cast(labels_train, tf.int32)
data_test = tf.cast(data_test, tf.float32)
labels_test = tf.cast(labels_test, tf.int32)
    
#=== Normalize Data ===#
data_train, data_test = data_train/255.0, data_test/255.0
data_train = tf.image.per_image_standardization(data_train) # Linearly scales each image to have mean 0 and variance 1
data_test = tf.image.per_image_standardization(data_test)   # Linearly scales each image to have mean 0 and variance 1

data_train = tf.reshape(data_train, (len(data_train), 28*28))
data_test = tf.reshape(data_test, (len(data_test), 28*28))

num_data_train = len(data_train)
num_data_test = len(data_test)
random_seed=1234
batch_size        = 1000

# %%
labels=tf.one_hot(tf.cast(labels_train,tf.int64), label_dimensions, dtype=tf.float32)

# %%
data_and_labels_train_full = tf.data.Dataset.from_tensor_slices((data_train, labels_train,labels)).shuffle(num_data_train, seed=random_seed)

# %%
data_and_labels_train = data_and_labels_train_full.take(num_data_train).batch(batch_size)
data_and_labels_val = data_and_labels_train_full.skip(num_data_train).batch(batch_size)    
num_batches_train = len(list(data_and_labels_train))
num_batches_val = len(list(data_and_labels_val))

# %%
for batch_num, (batch_data_train, batch_labels_train,labels) in data_and_labels_train.enumerate():
    batch=batch_num
    batch_data_train = batch_data_train
    batch_labels_train=batch_labels_train
    lab=labels

# %%
lab

# %%
y_true = tf.one_hot(tf.cast(labels_train,tf.int64), label_dimensions, dtype=tf.float32)

# %%
y_true

# %%
np.mean(tf.keras.losses.mean_squared_error(new_one, val[0:dimension[0]-1]))

# %%
x_train_new = batch_data_train[batch_labels_train == 1]
batch_pred_train,val=NN(x_train_new)

# %%
y_true = tf.one_hot(tf.cast(y_true,tf.int64), label_dimensions, dtype=tf.float32)

# %%
loss

# %%
np.linalg.norm(val[0]-val[1])
