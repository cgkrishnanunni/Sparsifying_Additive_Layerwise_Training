# %%
from decimal import Decimal # for filenames

import pdb #Equivalent of keyboard in MATLAB, just add "pdb.set_trace()"

import os
import sys

# %%
###############################################################################
#                       HyperParameters and RunOptions                        #
###############################################################################
class Hyperparameters:
    max_hidden_layers = 10# For this architecture, need at least 2. One for the mapping to the feature space, one as a trainable hidden layer. EXCLUDES MAPPING BACK TO DATA SPACE
    num_hidden_nodes  =100
    activation        = 'elu'
    classification_act= 'linear'
    model_constraint  =  25
    regularization    = 0.1
    manifold          = 0.000
    node_TOL          = 1e-4
    error_TOL         = 1e-4
    batch_size        = 500
    num_epochs        = 5000
    
    num_networks      = 6

# %%
import tensorflow as tf
from mat4py import loadmat
import numpy as np
import pandas as pd
from Utilities.plotting_sine import plot_sine
from Utilities.get_image_data import load_data
from Utilities.form_train_val_test_batches import form_train_val_test_batches
from Utilities.NN_FC_layerwise import FCLayerwise
from Utilities.NN_FC_layerwise_new import FCLayerwise_new
from Utilities.NETW import Final
from Utilities.Net import Final_Network
from Utilities.Net_new import Final_Network_ALGO_II
from Utilities.create_data import create_new
from Utilities.create_data_multiply import create_new_multiply
from Utilities.L2_error_computation import error_L2
from Utilities.loss_and_accuracies import data_loss_classification, data_loss_regression
from Utilities.manifold_regularization import manifold_classification
from Utilities.model_constraint import compute_interior_loss
from Utilities.model_constraint_weak import compute_interior_loss_weak
from Utilities.manifold_regularization_new import manifold_classification_new
from Utilities.optimize_layerwise import optimize
from Utilities.optimize_step_II import optimize_step
from Utilities.additive_output import net_output 
from Utilities.plot_and_save_figures_layerwise import plot_fig
from joblib import Parallel, delayed
import multiprocessing
import random

# %%
class Hyperparameters_new:
    max_hidden_layers = 3 # For this architecture, need at least 2. One for the mapping to the feature space, one as a trainable hidden layer. EXCLUDES MAPPING BACK TO DATA SPACE
    num_hidden_nodes  = 20
    activation        = 'elu'
    classification_act= 'linear'
    regularization    = 0.000
    manifold          = 0.000
    model_constraint  =  60
    node_TOL          = 1e-4
    error_TOL         = 1e-4
    batch_size        = 500
    num_epochs        = 5000

# %%
class RunOptions:
    def __init__(self):    
        #=== Choose Which GPU to Use ===#
        self.which_gpu = '1'
        
        #=== Use L_1 Regularization ===#
        self.use_L1 = 1
        
        #=== Choose Data Set ===#
        self.data_MNIST = 0
        self.data_CIFAR10 = 0 
        self.data_CIFAR100 = 0
        self.data_regression=1
        
        #=== Random Seed ===#
        self.random_seed = 1234

# %%
###############################################################################
#                                 File Paths                                  #
###############################################################################         
class FilePaths():    
    def __init__(self, hyperp, run_options):  
        #=== Declaring File Name Components ===# 
        self.NN_type = 'FC'
        if run_options.data_MNIST == 1:
            self.dataset = 'MNIST'
        if run_options.data_CIFAR10 == 1:
            self.dataset = 'CIFAR10'
        if run_options.data_CIFAR100 == 1:
            self.dataset = 'CIFAR100'
        if run_options.data_regression == 1:
            self.dataset = 'Abalone'
        if hyperp.regularization >= 1:
            hyperp.regularization = int(hyperp.regularization)
            regularization_string = str(hyperp.regularization)
        else:
            regularization_string = str(hyperp.regularization)
            regularization_string = 'pt' + regularization_string[2:]                        
        node_TOL_string = str('%.2e' %Decimal(hyperp.node_TOL))
        node_TOL_string = node_TOL_string[-1]
        error_TOL_string = str('%.2e' %Decimal(hyperp.error_TOL))
        error_TOL_string = error_TOL_string[-1]
        
        #=== File Name ===#
        if run_options.use_L1 == 0:
            self.filename = self.dataset + '_' + self.NN_type + '_mhl%d_hl%d_eTOL%s_b%d_e%d' %(hyperp.max_hidden_layers, hyperp.num_hidden_nodes, error_TOL_string, hyperp.batch_size, hyperp.num_epochs)
        else:
            self.filename = self.dataset + '_' + self.NN_type + '_L1_mhl%d_hl%d_r%s_nTOL%s_eTOL%s_b%d_e%d' %(hyperp.max_hidden_layers, hyperp.num_hidden_nodes, regularization_string, node_TOL_string, error_TOL_string, hyperp.batch_size, hyperp.num_epochs)

        #=== Saving Trained Neural Network and Tensorboard ===#
        #self.NN_savefile_directory = 'C:/Users/Chandradut/Desktop/Sparse training/Trained_NNs/' + self.filename # Since we need to save four different types of files to save a neural network model, we need to create a new folder for each model
        self.NN_savefile_directory =  self.filename
        self.NN_savefile_name = self.NN_savefile_directory + '/' + self.filename # The file path and name for the four files
        #self.tensorboard_directory = 'C:/Users/Chandradut/Desktop/Sparse training/Tensorboard/' + self.filename

###############################################################################

# %%
if __name__ == "__main__":     

    trainable=6
    #=== Hyperparameters and Run Options ===#    
    hyperp = Hyperparameters()
    hyperp_new=Hyperparameters_new()
    run_options = RunOptions()
    

    #=== File Names ===#
    file_paths = FilePaths(hyperp, run_options)
    
    #=== Load Data ===#       
    data_train, labels_train,\
    data_test, labels_test,\
    data_input_shape, num_channels, label_dimensions\
    = load_data(file_paths.NN_type, file_paths.dataset, run_options.random_seed) 
    
    gauss_solution=np.loadtxt("gauss_solution.data")
    gauss_solution = tf.cast(gauss_solution,tf.float32)
    
    gauss_points = loadmat('gauss_points.mat')
    gauss_points=np.array(list(gauss_points.values()))[-1]
    gauss_points = tf.cast(gauss_points,tf.float32)
    
    gauss_points_new = loadmat('gauss_points_new.mat')
    gauss_points_new=np.array(list(gauss_points_new.values()))[-1]
    gauss_points_new = tf.cast(gauss_points_new,tf.float32)
    
    gauss_weights = loadmat('gauss_weights.mat')
    gauss_weights=np.array(list(gauss_weights.values()))[-1].squeeze(-1)
    
    gauss_weights_new = loadmat('gauss_weights_new.mat')
    gauss_weights_new=np.array(list(gauss_weights_new.values()))[-1].squeeze(-1)

    
    Coordinates = loadmat('Coordinates.mat')
    Coordinates=np.array(list(Coordinates.values()))[-1]
    Coordinates = tf.cast(Coordinates,tf.float32)
    
    
    Stiffness = loadmat('Stiffness.mat')
    Stiffness=np.array(list(Stiffness.values()))[-1]
    Stiffness = tf.cast(Stiffness,tf.float32)
    
    load = loadmat('observation.mat')
    load=np.array(list(load.values()))[-1]
    load=tf.cast(load,tf.float32)
    load=tf.reshape(load,(len(load),1))
    
    Solution = loadmat('Solution.mat')
    Solution=np.array(list(Solution.values()))[-1]
    Solution=tf.cast(Solution,tf.float32)
    Solution=tf.reshape(Solution,(len(Solution),1))
    
    

    v=[]
    for i in range(0,len(Solution)):
        if np.abs(Solution[i])<1e-10:
            v.append(i)
    
    #for i in range(1,hyperp.num_networks):
    for i in range(1,2):
    #=== Initiate training ===#
        #trainer(hyperp, run_options, file_paths,i) 
        if i>1:
            trainable=2

    
            
        if trainable==2:
        
        
        
            #=== GPU Settings ===#
            os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
            os.environ["CUDA_VISIBLE_DEVICES"] = run_options.which_gpu
    
            #=== Neural Network ===#
            if run_options.use_L1 == 0:
                kernel_regularizer = None
                bias_regularizer = None  
            else:
                kernel_regularizer = tf.keras.regularizers.l1(hyperp.regularization)
                bias_regularizer = tf.keras.regularizers.l1(hyperp.regularization)
            
            
            multiply=0
        
            if multiply==0:

                data_train,new_label,labels_train,load,Solution=create_new(data_train, labels_train,hyperp,hyperp_new, run_options, data_input_shape, label_dimensions,i,load,Stiffness,Coordinates,Solution)
        
            if multiply==1:

                data_train,new_label,labels_train=create_new_multiply(data_train, labels_train,hyperp,hyperp_new, run_options, data_input_shape, label_dimensions,i)
     
        #=== Construct Validation Set and Batches ===# 
            data_and_labels_train, data_and_labels_val, data_and_labels_test,\
            num_data_train, num_data_val, num_data_test,\
            num_batches_train, num_batches_val, num_batches_test,data_and_labels_train_new\
            = form_train_val_test_batches(data_train, labels_train, \
                                      data_test, labels_test, \
                                      hyperp.batch_size, new_label, run_options.random_seed)
        
        
        if i==1 and trainable==2:
            NN = FCLayerwise(hyperp, run_options, data_input_shape, label_dimensions,kernel_regularizer, bias_regularizer)    
            NN._set_inputs( data_train)
        if i>1:
            kernel_regularizer = None
            bias_regularizer = None
            NN = FCLayerwise_new(hyperp_new, run_options, data_input_shape, label_dimensions,kernel_regularizer, bias_regularizer) 
            NN._set_inputs( data_train)
    #=== Training ===#
    #                                 Training                                    #
###############################################################################
        if trainable>2:
            del NN
            NN = Final(hyperp, run_options, data_input_shape, label_dimensions,kernel_regularizer, bias_regularizer,trainable)   
            #NN._set_inputs(data_train)
            NN.load_weights("WEIGHTS"+'/'+"model_weights"+str(1)+str(trainable-1))
            #NN=tf.keras.models.load_model("WEIGHTS"+'/'+"model"+str(1)+str(trainable-1))
        


        if i==1:
            hyperp_n=hyperp
            optimize(hyperp,hyperp_n, run_options, file_paths, NN, data_loss_classification, data_loss_regression, data_and_labels_train, data_and_labels_val, data_and_labels_test, label_dimensions, num_batches_train,data_and_labels_train_new,manifold_classification,hyperp.batch_size,run_options.random_seed,num_data_train,i,data_input_shape,data_train,labels_train,multiply,trainable,compute_interior_loss,gauss_points,gauss_weights,error_L2,gauss_solution,gauss_points_new,gauss_weights_new,Coordinates, Stiffness, load,Solution,v)   
        
        if i>1:
            hyperp_n=Hyperparameters_new()
            optimize_step(hyperp,hyperp_n, run_options, file_paths, NN, data_loss_classification, data_loss_regression, data_and_labels_train, data_and_labels_val, data_and_labels_test, label_dimensions, num_batches_train,data_and_labels_train_new,manifold_classification_new,hyperp.batch_size,run_options.random_seed,num_data_train,i,data_input_shape,data_train,labels_train,multiply,compute_interior_loss,gauss_points,gauss_weights,error_L2,gauss_solution,gauss_points_new,gauss_weights_new,Coordinates, Stiffness, load,Solution,v)   
        
        #NN.save("WEIGHTS"+'/'+"model"+str(1)+str(trainable))
        if not os.path.exists("WEIGHTS"):
            os.makedirs("WEIGHTS")
        NN.save_weights("WEIGHTS"+'/'+"model_weights"+str(1)+str(trainable))
        
        if i==1:
            plot_fig(hyperp, run_options, file_paths,i,trainable+1)
            
        if i>1:
            plot_fig(hyperp_new, run_options, file_paths,i,3)
        
        
        #plot_sine(hyperp,hyperp_new, data_test, run_options, data_input_shape, label_dimensions,2,data_train, labels_train)
# Out:
# ListWrapper([2, 100, 100, 1])
# Beginning Training
# ================================
#             Epoch 0
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Model: "final_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# W2 (Dense)                   multiple                  10100
# _________________________________________________________________
# W3 (Dense)                   multiple                  10100
# _________________________________________________________________
# W4 (Dense)                   multiple                  10100
# _________________________________________________________________
# W5 (Dense)                   multiple                  10100
# _________________________________________________________________
# W6 (Dense)                   multiple                  10100
# _________________________________________________________________
# upsampling_layer (Dense)     multiple                  300
# _________________________________________________________________
# classification_layer (Dense) multiple                  101
# =================================================================
# Total params: 50,901
# Trainable params: 10,201
# Non-trainable params: 40,700
# _________________________________________________________________
# Time per Batch: 0.05
# Time per Epoch: 0.80
#
# Training Set: Loss: 7.401e-01, Accuracy: 2973.722
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.452
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 1
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.78
#
# Training Set: Loss: 3.105e-01, Accuracy: 937.552
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.139
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 2
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 3.572e-01, Accuracy: 1266.401
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.119
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 3
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 3.193e-01, Accuracy: 1124.918
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.084
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 3.250e-01, Accuracy: 1158.953
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.147
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 5
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 2.436e-01, Accuracy: 801.405
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.053
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 6
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 2.841e-01, Accuracy: 1028.234
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.161
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 7
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.74
#
# Training Set: Loss: 1.946e-01, Accuracy: 624.767
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.038
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 8
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 2.435e-01, Accuracy: 882.563
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.163
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 9
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.76
#
# Training Set: Loss: 1.671e-01, Accuracy: 522.396
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.027
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 10
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.75
#
# Training Set: Loss: 2.145e-01, Accuracy: 765.581
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.166
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 11
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 1.434e-01, Accuracy: 450.331
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.022
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 12
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 1.956e-01, Accuracy: 678.423
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.171
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 13
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 1.316e-01, Accuracy: 396.861
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.018
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 14
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 1.742e-01, Accuracy: 611.630
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.171
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 15
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.74
#
# Training Set: Loss: 1.181e-01, Accuracy: 355.576
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.017
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 16
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 1.596e-01, Accuracy: 554.109
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.168
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 17
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.75
#
# Training Set: Loss: 1.088e-01, Accuracy: 322.750
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.017
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 18
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 1.483e-01, Accuracy: 507.110
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.165
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 19
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 1.009e-01, Accuracy: 294.458
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.016
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 20
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.74
#
# Training Set: Loss: 1.382e-01, Accuracy: 466.483
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.160
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 21
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 9.494e-02, Accuracy: 271.351
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.016
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 22
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.74
#
# Training Set: Loss: 1.271e-01, Accuracy: 429.714
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.151
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 23
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 8.759e-02, Accuracy: 251.188
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.016
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 24
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 1.218e-01, Accuracy: 398.128
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.142
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 25
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.74
#
# Training Set: Loss: 8.342e-02, Accuracy: 233.183
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.016
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 26
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 1.118e-01, Accuracy: 370.720
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.134
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 27
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 7.806e-02, Accuracy: 216.884
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.016
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 28
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 1.058e-01, Accuracy: 346.665
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.125
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 29
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 7.502e-02, Accuracy: 202.710
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.015
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 30
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.79
#
# Training Set: Loss: 1.010e-01, Accuracy: 325.282
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.118
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 31
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.76
#
# Training Set: Loss: 7.255e-02, Accuracy: 190.455
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.015
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 32
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 9.601e-02, Accuracy: 305.689
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.111
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 33
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.78
#
# Training Set: Loss: 6.978e-02, Accuracy: 179.952
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.015
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 34
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.76
#
# Training Set: Loss: 9.108e-02, Accuracy: 289.047
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.105
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 35
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.75
#
# Training Set: Loss: 6.646e-02, Accuracy: 170.418
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.014
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 36
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.75
#
# Training Set: Loss: 8.864e-02, Accuracy: 274.498
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.100
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 37
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 6.328e-02, Accuracy: 161.947
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.014
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 38
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.72
#
# Training Set: Loss: 8.516e-02, Accuracy: 261.400
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.095
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 39
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 6.133e-02, Accuracy: 154.654
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.013
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 40
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.75
#
# Training Set: Loss: 8.186e-02, Accuracy: 249.724
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.090
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 41
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.76
#
# Training Set: Loss: 5.946e-02, Accuracy: 148.355
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.013
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 42
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.75
#
# Training Set: Loss: 7.942e-02, Accuracy: 239.322
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.084
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 43
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.75
#
# Training Set: Loss: 5.798e-02, Accuracy: 142.564
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.013
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 44
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 7.654e-02, Accuracy: 229.858
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.079
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 45
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.75
#
# Training Set: Loss: 5.567e-02, Accuracy: 137.424
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.012
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 46
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.75
#
# Training Set: Loss: 7.379e-02, Accuracy: 221.433
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.074
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 47
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 5.478e-02, Accuracy: 132.763
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.012
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 48
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.77
#
# Training Set: Loss: 7.233e-02, Accuracy: 213.782
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.069
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 49
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.77
#
# Training Set: Loss: 5.337e-02, Accuracy: 128.588
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.012
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 50
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.77
#
# Training Set: Loss: 7.076e-02, Accuracy: 206.743
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.064
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 51
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 5.326e-02, Accuracy: 124.999
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.012
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 52
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 6.906e-02, Accuracy: 200.290
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.060
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 53
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.74
#
# Training Set: Loss: 5.132e-02, Accuracy: 121.702
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.011
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 54
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 6.691e-02, Accuracy: 194.549
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.056
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 55
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.74
#
# Training Set: Loss: 5.079e-02, Accuracy: 118.581
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.011
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 56
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 6.583e-02, Accuracy: 189.254
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.054
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 57
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 4.922e-02, Accuracy: 115.667
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.011
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 58
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.74
#
# Training Set: Loss: 6.264e-02, Accuracy: 184.371
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.051
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 59
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.76
#
# Training Set: Loss: 4.835e-02, Accuracy: 112.965
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.011
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 60
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 6.330e-02, Accuracy: 179.857
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.048
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 61
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 4.780e-02, Accuracy: 110.385
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.011
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 62
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 6.122e-02, Accuracy: 175.695
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.046
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 63
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.80
#
# Training Set: Loss: 4.642e-02, Accuracy: 107.957
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.011
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 64
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.75
#
# Training Set: Loss: 6.208e-02, Accuracy: 171.765
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.044
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 65
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.77
#
# Training Set: Loss: 4.549e-02, Accuracy: 105.701
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.011
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 66
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 6.006e-02, Accuracy: 168.006
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.042
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 67
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.76
#
# Training Set: Loss: 4.509e-02, Accuracy: 103.600
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.011
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 68
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 5.897e-02, Accuracy: 164.486
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.040
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 69
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.75
#
# Training Set: Loss: 4.504e-02, Accuracy: 101.609
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.012
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 70
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.77
#
# Training Set: Loss: 5.826e-02, Accuracy: 161.140
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.038
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 71
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.74
#
# Training Set: Loss: 4.352e-02, Accuracy: 99.728
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.012
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 72
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 5.756e-02, Accuracy: 157.958
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.037
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 73
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.75
#
# Training Set: Loss: 4.379e-02, Accuracy: 97.946
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.012
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 74
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 5.505e-02, Accuracy: 154.945
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.035
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 75
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 4.298e-02, Accuracy: 96.237
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.012
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 76
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 5.503e-02, Accuracy: 152.059
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.034
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 77
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.75
#
# Training Set: Loss: 4.259e-02, Accuracy: 94.610
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.012
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 78
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 5.550e-02, Accuracy: 149.308
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.032
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 79
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 4.215e-02, Accuracy: 93.048
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.013
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 80
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 5.377e-02, Accuracy: 146.667
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.031
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 81
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 4.132e-02, Accuracy: 91.551
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.013
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 82
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.75
#
# Training Set: Loss: 5.330e-02, Accuracy: 144.138
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.030
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 83
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 4.186e-02, Accuracy: 90.122
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.013
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 84
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.74
#
# Training Set: Loss: 5.145e-02, Accuracy: 141.692
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.029
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 85
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.71
#
# Training Set: Loss: 4.028e-02, Accuracy: 88.748
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.013
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 86
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 5.290e-02, Accuracy: 139.332
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.028
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 87
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 4.035e-02, Accuracy: 87.414
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.013
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 88
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 5.077e-02, Accuracy: 137.052
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.027
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 89
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 4.056e-02, Accuracy: 86.141
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.013
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 90
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 5.006e-02, Accuracy: 134.880
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.026
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 91
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 3.924e-02, Accuracy: 84.887
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.014
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 92
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.71
#
# Training Set: Loss: 4.954e-02, Accuracy: 132.769
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.026
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 93
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.71
#
# Training Set: Loss: 3.892e-02, Accuracy: 83.643
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.014
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 94
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.71
#
# Training Set: Loss: 4.990e-02, Accuracy: 130.798
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.025
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 95
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 3.910e-02, Accuracy: 82.438
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.014
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 96
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 4.946e-02, Accuracy: 128.793
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.024
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 97
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 3.867e-02, Accuracy: 81.315
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.014
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 98
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.71
#
# Training Set: Loss: 4.894e-02, Accuracy: 126.871
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.023
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 99
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.76
#
# Training Set: Loss: 3.894e-02, Accuracy: 80.216
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.014
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 100
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 4.882e-02, Accuracy: 125.007
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.023
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 101
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 3.730e-02, Accuracy: 79.141
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.015
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 102
# ...
#             Epoch 4972
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 2.245e-02, Accuracy: 23.869
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4973
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 2.207e-02, Accuracy: 20.420
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4974
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 2.278e-02, Accuracy: 23.905
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4975
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.74
#
# Training Set: Loss: 2.216e-02, Accuracy: 20.409
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4976
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 2.272e-02, Accuracy: 23.869
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4977
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 2.250e-02, Accuracy: 20.423
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4978
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 2.257e-02, Accuracy: 23.871
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4979
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.70
#
# Training Set: Loss: 2.219e-02, Accuracy: 20.432
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4980
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 2.283e-02, Accuracy: 23.850
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4981
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.77
#
# Training Set: Loss: 2.222e-02, Accuracy: 20.435
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4982
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 2.257e-02, Accuracy: 23.855
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4983
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.75
#
# Training Set: Loss: 2.184e-02, Accuracy: 20.435
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4984
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 2.244e-02, Accuracy: 23.822
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4985
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 2.176e-02, Accuracy: 20.464
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4986
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 2.284e-02, Accuracy: 23.803
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4987
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.77
#
# Training Set: Loss: 2.193e-02, Accuracy: 20.487
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4988
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.74
#
# Training Set: Loss: 2.258e-02, Accuracy: 23.764
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4989
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 2.207e-02, Accuracy: 20.517
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4990
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.77
#
# Training Set: Loss: 2.272e-02, Accuracy: 23.754
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4991
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 2.208e-02, Accuracy: 20.497
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4992
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 2.219e-02, Accuracy: 23.779
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4993
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.73
#
# Training Set: Loss: 2.210e-02, Accuracy: 20.491
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4994
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 2.276e-02, Accuracy: 23.789
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4995
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.72
#
# Training Set: Loss: 2.216e-02, Accuracy: 20.455
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4996
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.03
# Time per Epoch: 0.73
#
# Training Set: Loss: 2.245e-02, Accuracy: 23.812
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4997
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.76
#
# Training Set: Loss: 2.184e-02, Accuracy: 20.433
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4998
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.74
#
# Training Set: Loss: 2.255e-02, Accuracy: 23.835
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.004
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4999
# ================================
# Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000
# Trainable Hidden Layer Index: 6
# GPU: 1
#
# Optimizing 10 batches of size 500:
# Time per Batch: 0.04
# Time per Epoch: 0.75
#
# Training Set: Loss: 2.190e-02, Accuracy: 20.440
# Validation Set: Loss: 0.000e+00, Accuracy: 0.000
# Test Set: Loss: 0.000e+00, Accuracy: 0.005
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#      Extending Architecture
# ================================
# Previous Layer Relative # of 0s: 0.6869307
#
# L2 error: 1.310e-04
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-addaf1b99fce> in <module>
#     140
#     141         if i==1:
# --> 142             plot_fig(hyperp, run_options, file_paths,i,trainable+1)
#     143
#     144         if i>1:
#
# /workspace/krish/Sparsifying_Additive_Layerwise_Training/PINNS_COMPLEX_ONLY_ALGO_I/REGRESSION_PDE_MODEL_CONSTRAINTED/Utilities/plot_and_save_figures_layerwise.py in plot_fig(hyperp, run_options, file_paths, i_val, max_hidden_layers)
#      24
#      25
# ---> 26         df_metrics =pd.read_csv(name)
#      27
#      28         array_metrics = df_metrics.to_numpy()
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000/Abalone_FC_L1_mhl10_hl100_rpt1_nTOL4_eTOL4_b500_e5000_metrics_hl21.csv'

# %%
    import matplotlib.pyplot as plt
    
    storage_loss_array=[]
    
    no_epoch=hyperp.num_epochs
    
    for i in range(2,4):
    
        trainable_hidden_layer_index=i
    
    
        name=file_paths.NN_savefile_name + "_metrics_hl" + str(trainable_hidden_layer_index) +str(1)+ '.csv'


        df_metrics =pd.read_csv(name)

        array_metrics = df_metrics.to_numpy()

        
 
        storage_loss_array=np.concatenate((storage_loss_array, array_metrics[:,0]), axis=0)
    
    fig_accuracy = plt.figure()
    x_axis = np.linspace(1, len(storage_loss_array), len(storage_loss_array), endpoint = True)
    plt.plot(x_axis, storage_loss_array)
    #plt.ylim(-5, 60)

#plt.title('Accuracy for: ' + run_options.filename)
    plt.title('Test Loss plot with layer adaptation ')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
data_train
# Out:
# <tf.Tensor: id=16693, shape=(5000, 2), dtype=float32, numpy=
# array([[0.696799  , 0.5       ],
#        [0.        , 0.15995109],
#        [0.74418575, 0.5       ],
#        ...,
#        [0.5982862 , 0.5       ],
#        [0.        , 0.6563306 ],
#        [1.        , 0.18497042]], dtype=float32)>

# %%
tf.math.reduce_sum(tf.keras.losses.MSE(Solution, pred))
# Out:
# <tf.Tensor: id=6744890, shape=(), dtype=float32, numpy=178.8639>

# %%
G=tf.linalg.inv(Stiffness)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-276fc87c6bd4> in <module>
# ----> 1 G=tf.linalg.inv(Stiffness)
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_linalg_ops.py in matrix_inverse(input, adjoint, name)
#    1464         _ctx._context_handle, _ctx._thread_local_data.device_name,
#    1465         "MatrixInverse", name, _ctx._post_execution_callbacks, input,
# -> 1466         "adjoint", adjoint)
#    1467       return _result
#    1468     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
    trainable=2
    #=== Hyperparameters and Run Options ===#    
    hyperp = Hyperparameters()
    hyperp_new=Hyperparameters_new()
    run_options = RunOptions()
    

    #=== File Names ===#
    file_paths = FilePaths(hyperp, run_options)
    
    #=== Load Data ===#       
    data_train, labels_train,\
    data_test, labels_test,\
    data_input_shape, num_channels, label_dimensions\
    = load_data(file_paths.NN_type, file_paths.dataset, run_options.random_seed)

# %%
len(data_train)
# Out:
# 4000

# %%
plot_sine(hyperp,hyperp_new, data_test, run_options, data_input_shape, label_dimensions,2,data_train, labels_train,labels_test)

# %%
labels_train
# Out:
# array([3, 0, 3, ..., 4, 1, 0], dtype=int32)

# %%
    Coordinates = loadmat('Coordinates.mat')
    Coordinates=np.array(list(Coordinates.values()))[-1]
    Coordinates = tf.cast(Coordinates,tf.float32)
    
    
    Stiffness = loadmat('Stiffness.mat')
    Stiffness=np.array(list(Stiffness.values()))[-1]
    Stiffness = tf.cast(Stiffness,tf.float32)
    
    load = loadmat('observation.mat')
    load=np.array(list(load.values()))[-1]
    load=tf.cast(load,tf.float32)
    load=tf.reshape(load,(len(load),1))

# %%
    solution = loadmat('Solution.mat')
    solution=np.array(list(solution.values()))[-1]
    solution=tf.cast(solution,tf.float32)
    solution=tf.reshape(solution,(len(solution),1))

# %%
tf.math.reduce_sum(tf.keras.losses.MSE(load, loss))
# Out:
# <tf.Tensor: id=5127044, shape=(), dtype=float32, numpy=2.9658818e-09>

# %%
loss=tf.matmul(Stiffness, Solution)

# %%
        #loss=tf.matmul(Stiffness, pred)
        pred,new = NN(Coordinates)
        X=tf.matmul(tf.transpose(pred-Solution),tf.transpose(Stiffness))
        Y=tf.matmul(X,Stiffness)
        Z=tf.matmul(Y,pred-Solution)

# %%
Z
# Out:
# <tf.Tensor: id=7178056, shape=(1, 1), dtype=float32, numpy=array([[251.45015]], dtype=float32)>

# %%
import mat4py as m4p
bb=list(loss)
load = {'x': bb}
m4p.savemat('observation.mat', load)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-6e88c8e6fcc1> in <module>
#       2 bb=list(loss)
#       3 load = {'x': bb}
# ----> 4 m4p.savemat('observation.mat', load)
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/mat4py/savemat.py in savemat(filename, data)
#     475     # write variables
#     476     for name, array in data.items():
# --> 477         write_compressed_var_array(fd, array, name)
#     478
#     479     fd.close()
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/mat4py/savemat.py in write_compressed_var_array(fd, array, name)
#     198     bd = BytesIO()
#     199
# --> 200     write_var_array(bd, array, name)
#     201
#     202     data = zlib.compress(bd.getvalue())
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/mat4py/savemat.py in write_var_array(fd, array, name)
#     303 def write_var_array(fd, array, name=''):
#     304     """Write variable array (of any supported type)"""
# --> 305     header, array = guess_header(array, name)
#     306     mc = header['mclass']
#     307     if mc in numeric_class_etypes:
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/mat4py/savemat.py in guess_header(array, name)
#     438     if not header:
#     439         raise ValueError(
# --> 440             'Only dicts, two dimensional numeric, '
#     441             'and char arrays are currently supported')
#     442     header['name'] = name
#
# ValueError: Only dicts, two dimensional numeric, and char arrays are currently supported

# %%
loss_final=tf.math.reduce_sum(loss_new)

# %%
pred,l=NN(Coordinates )

# %%
pred
# Out:
# <tf.Tensor: id=17715, shape=(961, 1), dtype=float32, numpy=
# array([[0.9965409 ],
#        [0.97466844],
#        [1.016253  ],
#        [0.95278144],
#        [0.9943896 ],
#        [1.0359524 ],
#        [0.9308796 ],
#        [0.97251153],
#        [1.0140978 ],
#        [1.0556387 ],
#        [0.90896285],
#        [0.9506185 ],
#        [0.99222857],
#        [1.0337929 ],
#        [1.0753115 ],
#        [0.8870313 ],
#        [0.9287108 ],
#        [0.9703443 ],
#        [1.0119323 ],
#        [1.0534745 ],
#        [1.0949715 ],
#        [0.8650848 ],
#        [0.9067881 ],
#        [0.94844544],
#        [0.9900569 ],
#        [1.0316228 ],
#        [1.0731431 ],
#        [1.1146182 ],
#        [0.8431233 ],
#        [0.88485044],
#        [0.92653155],
#        [0.9681667 ],
#        [1.0097562 ],
#        [1.0513002 ],
#        [1.0927986 ],
#        [1.1342517 ],
#        [0.82114685],
#        [0.8628979 ],
#        [0.90460277],
#        [0.94626164],
#        [0.98787487],
#        [1.0294422 ],
#        [1.0709642 ],
#        [1.1124408 ],
#        [1.1538724 ],
#        [0.79915524],
#        [0.8409303 ],
#        [0.88265896],
#        [0.9243417 ],
#        [0.96597856],
#        [1.0075698 ],
#        [1.0491152 ],
#        [1.0906153 ],
#        [1.1320701 ],
#        [1.1734799 ],
#        [0.7771485 ],
#        [0.81894755],
#        [0.86070025],
#        [0.9024067 ],
#        [0.94406736],
#        [0.98568225],
#        [1.0272514 ],
#        [1.0687749 ],
#        [1.1102532 ],
#        [1.1516861 ],
#        [1.1930742 ],
#        [0.75512666],
#        [0.79694974],
#        [0.83872646],
#        [0.8804569 ],
#        [0.9221413 ],
#        [0.96377987],
#        [1.0053725 ],
#        [1.0469198 ],
#        [1.0884215 ],
#        [1.1298779 ],
#        [1.1712892 ],
#        [1.2126557 ],
#        [0.7330896 ],
#        [0.7749368 ],
#        [0.8167376 ],
#        [0.85849196],
#        [0.90020025],
#        [0.9418626 ],
#        [0.983479  ],
#        [1.0250498 ],
#        [1.0665752 ],
#        [1.108055  ],
#        [1.1494895 ],
#        [1.1908792 ],
#        [1.2322239 ],
#        [0.7110374 ],
#        [0.7529087 ],
#        [0.7947335 ],
#        [0.83651197],
#        [0.87824416],
#        [0.9199303 ],
#        [0.9615705 ],
#        [1.003165  ],
#        [1.0447137 ],
#        [1.0862172 ],
#        [1.1276752 ],
#        [1.1690882 ],
#        [1.210456  ],
#        [1.2517792 ],
#        [0.68896985],
#        [0.7308654 ],
#        [0.7727144 ],
#        [0.8145168 ],
#        [0.85627294],
#        [0.89798295],
#        [0.93964696],
#        [0.9812651 ],
#        [1.0228375 ],
#        [1.0643646 ],
#        [1.1058463 ],
#        [1.1472825 ],
#        [1.1886737 ],
#        [1.23002   ],
#        [1.2713217 ],
#        [0.66688704],
#        [0.7088069 ],
#        [0.75067997],
#        [0.79250646],
#        [0.83428663],
#        [0.87602055],
#        [0.9177084 ],
#        [0.95935035],
#        [1.0009465 ],
#        [1.0424972 ],
#        [1.0840021 ],
#        [1.1254619 ],
#        [1.1668766 ],
#        [1.2082461 ],
#        [1.249571  ],
#        [1.290851  ],
#        [0.64478886],
#        [0.6867329 ],
#        [0.7286303 ],
#        [0.770481  ],
#        [0.8122853 ],
#        [0.8540431 ],
#        [0.89575493],
#        [0.9374206 ],
#        [0.97904056],
#        [1.0206147 ],
#        [1.0621434 ],
#        [1.1036266 ],
#        [1.1450647 ],
#        [1.1864578 ],
#        [1.2278057 ],
#        [1.2691089 ],
#        [1.3103676 ],
#        [0.6226753 ],
#        [0.6646437 ],
#        [0.7065654 ],
#        [0.74844027],
#        [0.7902686 ],
#        [0.8320506 ],
#        [0.8737862 ],
#        [0.91547585],
#        [0.95711946],
#        [0.9987174 ],
#        [1.0402697 ],
#        [1.0817765 ],
#        [1.123238  ],
#        [1.1646544 ],
#        [1.2060256 ],
#        [1.2473522 ],
#        [1.288634  ],
#        [1.329871  ],
#        [0.60054624],
#        [0.6425392 ],
#        [0.684485  ],
#        [0.72638416],
#        [0.76823676],
#        [0.81004274],
#        [0.85180247],
#        [0.89351606],
#        [0.9351836 ],
#        [0.9768052 ],
#        [1.0183811 ],
#        [1.0599116 ],
#        [1.1013967 ],
#        [1.1428363 ],
#        [1.184231  ],
#        [1.2255808 ],
#        [1.2668856 ],
#        [1.3081459 ],
#        [1.3493618 ],
#        [0.5784018 ],
#        [0.62041914],
#        [0.66238946],
#        [0.70431304],
#        [0.74618965],
#        [0.78801984],
#        [0.8298035 ],
#        [0.87154114],
#        [0.9132325 ],
#        [0.954878  ],
#        [0.9964776 ],
#        [1.0380317 ],
#        [1.0795404 ],
#        [1.1210035 ],
#        [1.1624216 ],
#        [1.2037946 ],
#        [1.2451228 ],
#        [1.2864063 ],
#        [1.3276452 ],
#        [1.3688396 ],
#        [0.55624187],
#        [0.59828377],
#        [0.64027846],
#        [0.6822263 ],
#        [0.7241273 ],
#        [0.7659817 ],
#        [0.80778956],
#        [0.849551  ],
#        [0.89126635],
#        [0.93293566],
#        [0.9745592 ],
#        [1.016137  ],
#        [1.057669  ],
#        [1.0991558 ],
#        [1.1405975 ],
#        [1.1819938 ],
#        [1.2233453 ],
#        [1.2646519 ],
#        [1.305914  ],
#        [1.3471316 ],
#        [1.3883047 ],
#        [0.5340663 ],
#        [0.57613283],
#        [0.61815214],
#        [0.6601243 ],
#        [0.7020496 ],
#        [0.7439282 ],
#        [0.78576016],
#        [0.8275458 ],
#        [0.86928505],
#        [0.91097844],
#        [0.95262563],
#        [0.9942271 ],
#        [1.0357829 ],
#        [1.0772934 ],
#        [1.1187583 ],
#        [1.1601783 ],
#        [1.201553  ],
#        [1.2428831 ],
#        [1.2841681 ],
#        [1.3254088 ],
#        [1.3666052 ],
#        [1.4077569 ],
#        [0.5118753 ],
#        [0.5539664 ],
#        [0.59601015],
#        [0.6380068 ],
#        [0.67995644],
#        [0.7218594 ],
#        [0.76371557],
#        [0.8055253 ],
#        [0.84728867],
#        [0.8890059 ],
#        [0.93067706],
#        [0.9723023 ],
#        [1.0138819 ],
#        [1.055416  ],
#        [1.0969045 ],
#        [1.1383479 ],
#        [1.179746  ],
#        [1.2210993 ],
#        [1.2624079 ],
#        [1.3036715 ],
#        [1.3448908 ],
#        [1.3860657 ],
#        [1.4271964 ],
#        [0.48966834],
#        [0.53178406],
#        [0.5738524 ],
#        [0.6158736 ],
#        [0.65784776],
#        [0.6997749 ],
#        [0.7416554 ],
#        [0.78348935],
#        [0.82527673],
#        [0.86701804],
#        [0.9087131 ],
#        [0.9503623 ],
#        [0.99196565],
#        [1.0335232 ],
#        [1.0750355 ],
#        [1.1165023 ],
#        [1.157924  ],
#        [1.1993008 ],
#        [1.2406323 ],
#        [1.2819194 ],
#        [1.323162  ],
#        [1.3643599 ],
#        [1.4055135 ],
#        [1.4466231 ],
#        [0.46744543],
#        [0.5095859 ],
#        [0.5516789 ],
#        [0.5937247 ],
#        [0.6357233 ],
#        [0.6776749 ],
#        [0.7195797 ],
#        [0.7614378 ],
#        [0.8032495 ],
#        [0.8450148 ],
#        [0.8867339 ],
#        [0.9284068 ],
#        [0.970034  ],
#        [1.0116154 ],
#        [1.0531512 ],
#        [1.0946418 ],
#        [1.136087  ],
#        [1.1774869 ],
#        [1.218842  ],
#        [1.2601523 ],
#        [1.301418  ],
#        [1.3426389 ],
#        [1.3838156 ],
#        [1.4249482 ],
#        [1.4660367 ],
#        [0.4452064 ],
#        [0.4873719 ],
#        [0.52948964],
#        [0.57155997],
#        [0.6135831 ],
#        [0.6555592 ],
#        [0.69748837],
#        [0.7393707 ],
#        [0.7812065 ],
#        [0.822996  ],
#        [0.8647391 ],
#        [0.9064361 ],
#        [0.9480871 ],
#        [0.98969233],
#        [1.031252  ],
#        [1.072766  ],
#        [1.1142347 ],
#        [1.1556581 ],
#        [1.1970367 ],
#        [1.2383703 ],
#        [1.2796592 ],
#        [1.3209034 ],
#        [1.3621031 ],
#        [1.4032587 ],
#        [1.4443699 ],
#        [1.4854374 ],
#        [0.4229513 ],
#        [0.46514183],
#        [0.5072844 ],
#        [0.54937947],
#        [0.5914271 ],
#        [0.63342774],
#        [0.6753813 ],
#        [0.717288  ],
#        [0.7591481 ],
#        [0.80096173],
#        [0.842729  ],
#        [0.88444984],
#        [0.9261249 ],
#        [0.9677539 ],
#        [1.0093373 ],
#        [1.0508751 ],
#        [1.0923673 ],
#        [1.1338143 ],
#        [1.1752163 ],
#        [1.2165732 ],
#        [1.2578853 ],
#        [1.2991527 ],
#        [1.3403758 ],
#        [1.3815542 ],
#        [1.4226886 ],
#        [1.4637787 ],
#        [1.5048252 ],
#        [0.4006801 ],
#        [0.44289565],
#        [0.48506325],
#        [0.527183  ],
#        [0.5692554 ],
#        [0.61128056],
#        [0.6532586 ],
#        [0.6951898 ],
#        [0.73707414],
#        [0.7789118 ],
#        [0.82070327],
#        [0.8624483 ],
#        [0.9041472 ],
#        [0.9458002 ],
#        [0.9874073 ],
#        [1.0289688 ],
#        [1.0704848 ],
#        [1.1119555 ],
#        [1.1533808 ],
#        [1.1947612 ],
#        [1.2360965 ],
#        [1.2773873 ],
#        [1.3186333 ],
#        [1.359835  ],
#        [1.4009924 ],
#        [1.4421055 ],
#        [1.4831747 ],
#        [1.5242    ],
#        [0.3783926 ],
#        [0.42063332],
#        [0.462826  ],
#        [0.5049708 ],
#        [0.5470679 ],
#        [0.5891175 ],
#        [0.63112015],
#        [0.6730757 ],
#        [0.7149845 ],
#        [0.75684655],
#        [0.798662  ],
#        [0.8404312 ],
#        [0.88215417],
#        [0.9238311 ],
#        [0.9654621 ],
#        [1.0070473 ],
#        [1.0485871 ],
#        [1.0900812 ],
#        [1.1315302 ],
#        [1.1729339 ],
#        [1.2142928 ],
#        [1.2556068 ],
#        [1.2968762 ],
#        [1.3381008 ],
#        [1.3792813 ],
#        [1.4204173 ],
#        [1.4615095 ],
#        [1.5025576 ],
#        [1.543562  ],
#        [0.35608894],
#        [0.3983549 ],
#        [0.44057268],
#        [0.48274243],
#        [0.5248644 ],
#        [0.56693876],
#        [0.6089659 ],
#        [0.6509459 ],
#        [0.6928792 ],
#        [0.7347655 ],
#        [0.7766053 ],
#        [0.8183986 ],
#        [0.8601456 ],
#        [0.9018465 ],
#        [0.9435015 ],
#        [0.9851105 ],
#        [1.0266739 ],
#        [1.0681919 ],
#        [1.1096643 ],
#        [1.1510917 ],
#        [1.1924739 ],
#        [1.2338113 ],
#        [1.2751039 ],
#        [1.3163519 ],
#        [1.3575553 ],
#        [1.3987145 ],
#        [1.4398295 ],
#        [1.4809006 ],
#        [1.5219277 ],
#        [1.5629112 ],
#        [0.33376905],
#        [0.37606025],
#        [0.41830313],
#        [0.460498  ],
#        [0.5026449 ],
#        [0.54474413],
#        [0.5867959 ],
#        [0.62880045],
#        [0.6707581 ],
#        [0.7126689 ],
#        [0.75453293],
#        [0.7963505 ],
#        [0.83812165],
#        [0.8798466 ],
#        [0.92152536],
#        [0.9631585 ],
#        [1.0047458 ],
#        [1.0462872 ],
#        [1.0877835 ],
#        [1.1292343 ],
#        [1.17064   ],
#        [1.2120007 ],
#        [1.2533168 ],
#        [1.2945879 ],
#        [1.3358145 ],
#        [1.3769969 ],
#        [1.4181348 ],
#        [1.4592288 ],
#        [1.5002788 ],
#        [1.5412849 ],
#        [1.5822475 ],
#        [0.35374928],
#        [0.39601743],
#        [0.4382374 ],
#        [0.48040938],
#        [0.52253366],
#        [0.56461006],
#        [0.60663927],
#        [0.6486214 ],
#        [0.6905565 ],
#        [0.7324449 ],
#        [0.7742868 ],
#        [0.81608206],
#        [0.8578311 ],
#        [0.899534  ],
#        [0.94119096],
#        [0.98280203],
#        [1.0243673 ],
#        [1.065887  ],
#        [1.1073618 ],
#        [1.148791  ],
#        [1.1901753 ],
#        [1.2315143 ],
#        [1.2728089 ],
#        [1.314059  ],
#        [1.3552643 ],
#        [1.3964254 ],
#        [1.4375421 ],
#        [1.478615  ],
#        [1.5196443 ],
#        [1.5606294 ],
#        [0.37371555],
#        [0.4159607 ],
#        [0.45815775],
#        [0.5003069 ],
#        [0.5424082 ],
#        [0.5844621 ],
#        [0.6264688 ],
#        [0.6684284 ],
#        [0.7103413 ],
#        [0.75220746],
#        [0.794027  ],
#        [0.83580023],
#        [0.87752724],
#        [0.91920793],
#        [0.9608431 ],
#        [1.0024322 ],
#        [1.0439758 ],
#        [1.085474  ],
#        [1.1269269 ],
#        [1.1683345 ],
#        [1.2096972 ],
#        [1.251015  ],
#        [1.2922882 ],
#        [1.3335165 ],
#        [1.3747009 ],
#        [1.4158406 ],
#        [1.4569366 ],
#        [1.4979886 ],
#        [1.5389968 ],
#        [0.3936677 ],
#        [0.43588996],
#        [0.4780642 ],
#        [0.52019054],
#        [0.5622692 ],
#        [0.60430044],
#        [0.64628464],
#        [0.68822205],
#        [0.73011243],
#        [0.7719563 ],
#        [0.8137537 ],
#        [0.85550475],
#        [0.89720976],
#        [0.9388687 ],
#        [0.9804816 ],
#        [1.022049  ],
#        [1.063571  ],
#        [1.1050475 ],
#        [1.1464787 ],
#        [1.1878649 ],
#        [1.229206  ],
#        [1.2705024 ],
#        [1.3117543 ],
#        [1.3529617 ],
#        [1.3941244 ],
#        [1.4352435 ],
#        [1.4763182 ],
#        [1.5173492 ],
#        [0.41360587],
#        [0.45580527],
#        [0.49795663],
#        [0.5400603 ],
#        [0.5821163 ],
#        [0.62412524],
#        [0.6660869 ],
#        [0.7080018 ],
#        [0.74987   ],
#        [0.79169154],
#        [0.83346677],
#        [0.87519586],
#        [0.91687876],
#        [0.95851576],
#        [1.0001069 ],
#        [1.0416526 ],
#        [1.0831528 ],
#        [1.1246076 ],
#        [1.1660172 ],
#        [1.207382  ],
#        [1.2487018 ],
#        [1.289977  ],
#        [1.3312073 ],
#        [1.3723935 ],
#        [1.4135355 ],
#        [1.4546331 ],
#        [1.495687  ],
#        [0.4335302 ],
#        [0.4757067 ],
#        [0.5178353 ],
#        [0.5599162 ],
#        [0.6019497 ],
#        [0.643936  ],
#        [0.68587536],
#        [0.72776794],
#        [0.7696139 ],
#        [0.81141335],
#        [0.8531665 ],
#        [0.89487344],
#        [0.93653435],
#        [0.97814953],
#        [1.0197189 ],
#        [1.0612428 ],
#        [1.1027216 ],
#        [1.1441545 ],
#        [1.1855426 ],
#        [1.2268859 ],
#        [1.2681843 ],
#        [1.3094382 ],
#        [1.3506473 ],
#        [1.3918124 ],
#        [1.4329332 ],
#        [1.47401   ],
#        [0.45344055],
#        [0.49559423],
#        [0.5377002 ],
#        [0.5797584 ],
#        [0.62176937],
#        [0.6637331 ],
#        [0.7056503 ],
#        [0.74752045],
#        [0.7893443 ],
#        [0.8311216 ],
#        [0.87285274],
#        [0.91453767],
#        [0.9561768 ],
#        [0.99777   ],
#        [1.0393175 ],
#        [1.0808198 ],
#        [1.1222768 ],
#        [1.1636884 ],
#        [1.2050552 ],
#        [1.2463768 ],
#        [1.2876542 ],
#        [1.3288865 ],
#        [1.3700747 ],
#        [1.4112185 ],
#        [1.4523181 ],
#        [0.47333702],
#        [0.51546794],
#        [0.55755115],
#        [0.59958684],
#        [0.6415753 ],
#        [0.68351674],
#        [0.7254115 ],
#        [0.7672595 ],
#        [0.80906117],
#        [0.8508164 ],
#        [0.89252543],
#        [0.9341884 ],
#        [0.97580576],
#        [1.0173771 ],
#        [1.058903  ],
#        [1.1003838 ],
#        [1.141819  ],
#        [1.1832091 ],
#        [1.2245544 ],
#        [1.2658547 ],
#        [1.3071107 ],
#        [1.3483218 ],
#        [1.3894888 ],
#        [1.4306117 ],
#        [0.49321958],
#        [0.5353278 ],
#        [0.5773883 ],
#        [0.6194015 ],
#        [0.6613675 ],
#        [0.7032867 ],
#        [0.74515927],
#        [0.786985  ],
#        [0.82876456],
#        [0.8704977 ],
#        [0.9121848 ],
#        [0.9538259 ],
#        [0.9954213 ],
#        [1.0369711 ],
#        [1.0784754 ],
#        [1.1199342 ],
#        [1.161348  ],
#        [1.2027167 ],
#        [1.2440405 ],
#        [1.2853197 ],
#        [1.3265543 ],
#        [1.3677443 ],
#        [1.4088904 ],
#        [0.51308835],
#        [0.5551739 ],
#        [0.5972119 ],
#        [0.6392025 ],
#        [0.68114614],
#        [0.7230431 ],
#        [0.7648932 ],
#        [0.8066969 ],
#        [0.8484545 ],
#        [0.8901655 ],
#        [0.9318307 ],
#        [0.9734501 ],
#        [1.0150236 ],
#        [1.0565517 ],
#        [1.0980344 ],
#        [1.1394715 ],
#        [1.180864  ],
#        [1.2222114 ],
#        [1.2635138 ],
#        [1.3047715 ],
#        [1.3459849 ],
#        [1.3871539 ],
#        [0.53294337],
#        [0.5750062 ],
#        [0.6170216 ],
#        [0.65898985],
#        [0.70091116],
#        [0.7427858 ],
#        [0.78461385],
#        [0.82639545],
#        [0.86813074],
#        [0.9098201 ],
#        [0.95146334],
#        [0.9930609 ],
#        [1.0346128 ],
#        [1.0761191 ],
#        [1.11758   ],
#        [1.1589961 ],
#        [1.2003667 ],
#        [1.2416927 ],
#        [1.2829739 ],
#        [1.3242106 ],
#        [1.3654027 ],
#        [0.55278444],
#        [0.5948249 ],
#        [0.6368177 ],
#        [0.67876357],
#        [0.72066265],
#        [0.76251507],
#        [0.80432093],
#        [0.84608054],
#        [0.88779384],
#        [0.9294613 ],
#        [0.97108275],
#        [1.0126585 ],
#        [1.0541885 ],
#        [1.0956734 ],
#        [1.137113  ],
#        [1.1785071 ],
#        [1.2198566 ],
#        [1.2611612 ],
#        [1.3024211 ],
#        [1.3436365 ],
#        [0.5726118 ],
#        [0.6146297 ],
#        [0.65660024],
#        [0.69852376],
#        [0.7404006 ],
#        [0.7822308 ],
#        [0.82401466],
#        [0.86575216],
#        [0.9074436 ],
#        [0.9490891 ],
#        [0.9906888 ],
#        [1.0322428 ],
#        [1.0737512 ],
#        [1.1152143 ],
#        [1.1566325 ],
#        [1.1980054 ],
#        [1.2393333 ],
#        [1.2806166 ],
#        [1.3218554 ],
#        [0.59242564],
#        [0.6344209 ],
#        [0.6763691 ],
#        [0.71827036],
#        [0.7601249 ],
#        [0.80193305],
#        [0.8436948 ],
#        [0.8854105 ],
#        [0.9270799 ],
#        [0.9687037 ],
#        [1.0102816 ],
#        [1.051814  ],
#        [1.0933007 ],
#        [1.1347425 ],
#        [1.1761389 ],
#        [1.2174904 ],
#        [1.258797  ],
#        [1.3000592 ],
#        [0.6122258 ],
#        [0.6541985 ],
#        [0.6961243 ],
#        [0.7380035 ],
#        [0.77983594],
#        [0.8216219 ],
#        [0.8633618 ],
#        [0.90505546],
#        [0.94670314],
#        [0.988305  ],
#        [1.0298611 ],
#        [1.0713718 ],
#        [1.1128372 ],
#        [1.1542574 ],
#        [1.1956325 ],
#        [1.2369623 ],
#        [1.2782481 ],
#        [0.63201207],
#        [0.67396253],
#        [0.71586615],
#        [0.7577231 ],
#        [0.79953355],
#        [0.8412975 ],
#        [0.8830153 ],
#        [0.9246871 ],
#        [0.9663129 ],
#        [1.007893  ],
#        [1.0494275 ],
#        [1.0909165 ],
#        [1.1323606 ],
#        [1.1737591 ],
#        [1.2151126 ],
#        [1.2564216 ],
#        [0.65178496],
#        [0.69371307],
#        [0.73559445],
#        [0.7774292 ],
#        [0.81921744],
#        [0.86095953],
#        [0.90265554],
#        [0.94430524],
#        [0.9859095 ],
#        [1.0274677 ],
#        [1.0689808 ],
#        [1.1104482 ],
#        [1.1518705 ],
#        [1.1932479 ],
#        [1.2345803 ],
#        [0.6715441 ],
#        [0.71345   ],
#        [0.7553092 ],
#        [0.79712194],
#        [0.8388881 ],
#        [0.8806084 ],
#        [0.9222823 ],
#        [0.96391034],
#        [1.0054927 ],
#        [1.0470295 ],
#        [1.0885208 ],
#        [1.1299669 ],
#        [1.1713675 ],
#        [1.2127234 ],
#        [0.6912898 ],
#        [0.73317343],
#        [0.7750106 ],
#        [0.81680113],
#        [0.8585455 ],
#        [0.90024364],
#        [0.94189584],
#        [0.9835022 ],
#        [1.0250628 ],
#        [1.0665779 ],
#        [1.1080475 ],
#        [1.1494724 ],
#        [1.1908517 ],
#        [0.71102196],
#        [0.7528835 ],
#        [0.7946984 ],
#        [0.83646715],
#        [0.8781894 ],
#        [0.9198659 ],
#        [0.96149606],
#        [1.0030807 ],
#        [1.0446197 ],
#        [1.0861133 ],
#        [1.1275617 ],
#        [1.1689647 ],
#        [0.7307406 ],
#        [0.7725801 ],
#        [0.8143731 ],
#        [0.85611963],
#        [0.8978202 ],
#        [0.9394745 ],
#        [0.9810833 ],
#        [1.0226461 ],
#        [1.0641636 ],
#        [1.1056355 ],
#        [1.1470624 ],
#        [0.75044584],
#        [0.7922633 ],
#        [0.83403414],
#        [0.87575895],
#        [0.91743743],
#        [0.95907027],
#        [1.0006572 ],
#        [1.0421983 ],
#        [1.0836941 ],
#        [1.1251448 ],
#        [0.77013767],
#        [0.81193304],
#        [0.853682  ],
#        [0.8953847 ],
#        [0.9370416 ],
#        [0.9786526 ],
#        [1.0202178 ],
#        [1.0617377 ],
#        [1.1032119 ],
#        [0.7898162 ],
#        [0.83158946],
#        [0.8733165 ],
#        [0.91499746],
#        [0.95663255],
#        [0.9982219 ],
#        [1.0397655 ],
#        [1.0812635 ],
#        [0.8094812 ],
#        [0.85123247],
#        [0.8929378 ],
#        [0.9345969 ],
#        [0.97621024],
#        [1.0177778 ],
#        [1.0592998 ],
#        [0.82913274],
#        [0.87086225],
#        [0.9125457 ],
#        [0.95418304],
#        [0.9957747 ],
#        [1.0373207 ],
#        [0.8487712 ],
#        [0.89047873],
#        [0.9321404 ],
#        [0.9737561 ],
#        [1.015326  ],
#        [0.8683963 ],
#        [0.91008216],
#        [0.95172197],
#        [0.99331594],
#        [0.8880082 ],
#        [0.92967206],
#        [0.97129035],
#        [0.90760666],
#        [0.9492491 ],
#        [0.92719203]], dtype=float32)>

# %%
len(Solution)
# Out:
# 2601

# %%
    load = loadmat('observation.mat')
    load=np.array(list(load.values()))[-1]
    load=tf.cast(load,tf.float32)
    load=tf.reshape(load,(len(load),1))

# %%
len(load)
# Out:
# 961
