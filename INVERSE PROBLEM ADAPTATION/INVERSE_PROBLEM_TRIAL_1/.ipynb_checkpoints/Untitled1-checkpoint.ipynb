# %%
from decimal import Decimal # for filenames

import pdb #Equivalent of keyboard in MATLAB, just add "pdb.set_trace()"

import os
import sys

# %%
###############################################################################
#                       HyperParameters and RunOptions                        #
###############################################################################
class Hyperparameters:
    max_hidden_layers = 15 # For this architecture, need at least 2. One for the mapping to the feature space, one as a trainable hidden layer. EXCLUDES MAPPING BACK TO DATA SPACE
    num_hidden_nodes  = 100
    activation        = 'elu'
    classification_act= 'linear'
    regularization    = 0.0001
    manifold          = 0.001
    node_TOL          = 1e-4
    error_TOL         = 1e-4
    batch_size        = 20
    num_epochs        = 400
    
    num_networks      = 6

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from Utilities.get_image_data import load_data
from Utilities.form_train_val_test_batches import form_train_val_test_batches
from Utilities.NN_FC_layerwise import FCLayerwise
from Utilities.NN_FC_layerwise_new import FCLayerwise_new
from Utilities.NETW import Final
from Utilities.Net import Final_Network
from Utilities.Net_new import Final_Network_ALGO_II
from Utilities.create_data import create_new
from Utilities.create_data_multiply import create_new_multiply
from Utilities.loss_and_accuracies import data_loss_classification, data_loss_regression
from Utilities.manifold_regularization import manifold_classification
from Utilities.manifold_regularization_new import manifold_classification_new
from Utilities.optimize_layerwise import optimize
from Utilities.optimize_step_II import optimize_step
from Utilities.additive_output import net_output 
from Utilities.plot_and_save_figures_layerwise import plot_fig
from joblib import Parallel, delayed
import multiprocessing
import random

# %%
class Hyperparameters_new:
    max_hidden_layers = 3 # For this architecture, need at least 2. One for the mapping to the feature space, one as a trainable hidden layer. EXCLUDES MAPPING BACK TO DATA SPACE
    num_hidden_nodes  = 10
    activation        = 'elu'
    classification_act= 'linear'
    regularization    = 0.000
    manifold          = 0.000
    node_TOL          = 1e-4
    error_TOL         = 1e-4
    batch_size        = 100
    num_epochs        = 2000

# %%
class RunOptions:
    def __init__(self):    
        #=== Choose Which GPU to Use ===#
        self.which_gpu = '1'
        
        #=== Use L_1 Regularization ===#
        self.use_L1 = 1
        
        #=== Choose Data Set ===#
        self.data_MNIST = 0
        self.data_CIFAR10 = 0 
        self.data_CIFAR100 = 0
        self.data_regression=1
        
        #=== Random Seed ===#
        self.random_seed = 1234

# %%
###############################################################################
#                                 File Paths                                  #
###############################################################################         
class FilePaths():    
    def __init__(self, hyperp, run_options):  
        #=== Declaring File Name Components ===# 
        self.NN_type = 'FC'
        if run_options.data_MNIST == 1:
            self.dataset = 'MNIST'
        if run_options.data_CIFAR10 == 1:
            self.dataset = 'CIFAR10'
        if run_options.data_CIFAR100 == 1:
            self.dataset = 'CIFAR100'
        if run_options.data_regression == 1:
            self.dataset = 'Abalone'
        if hyperp.regularization >= 1:
            hyperp.regularization = int(hyperp.regularization)
            regularization_string = str(hyperp.regularization)
        else:
            regularization_string = str(hyperp.regularization)
            regularization_string = 'pt' + regularization_string[2:]                        
        node_TOL_string = str('%.2e' %Decimal(hyperp.node_TOL))
        node_TOL_string = node_TOL_string[-1]
        error_TOL_string = str('%.2e' %Decimal(hyperp.error_TOL))
        error_TOL_string = error_TOL_string[-1]
        
        #=== File Name ===#
        if run_options.use_L1 == 0:
            self.filename = self.dataset + '_' + self.NN_type + '_mhl%d_hl%d_eTOL%s_b%d_e%d' %(hyperp.max_hidden_layers, hyperp.num_hidden_nodes, error_TOL_string, hyperp.batch_size, hyperp.num_epochs)
        else:
            self.filename = self.dataset + '_' + self.NN_type + '_L1_mhl%d_hl%d_r%s_nTOL%s_eTOL%s_b%d_e%d' %(hyperp.max_hidden_layers, hyperp.num_hidden_nodes, regularization_string, node_TOL_string, error_TOL_string, hyperp.batch_size, hyperp.num_epochs)

        #=== Saving Trained Neural Network and Tensorboard ===#
        #self.NN_savefile_directory = 'C:/Users/Chandradut/Desktop/Sparse training/Trained_NNs/' + self.filename # Since we need to save four different types of files to save a neural network model, we need to create a new folder for each model
        self.NN_savefile_directory =  self.filename
        self.NN_savefile_name = self.NN_savefile_directory + '/' + self.filename # The file path and name for the four files
        #self.tensorboard_directory = 'C:/Users/Chandradut/Desktop/Sparse training/Tensorboard/' + self.filename

###############################################################################

# %%
if __name__ == "__main__":     
    
    
#for trainable in range(2,10):
    
    trainable=2
    #=== Hyperparameters and Run Options ===#    
    hyperp = Hyperparameters()
    hyperp_new=Hyperparameters_new()
    run_options = RunOptions()
    

    #=== File Names ===#
    file_paths = FilePaths(hyperp, run_options)
    
    #=== Load Data ===#       
    data_train, labels_train,\
    data_test, labels_test,\
    data_input_shape, num_channels, label_dimensions, labels_train_manifold, data_train_manifold, data_val, labels_val\
    = load_data(file_paths.NN_type, file_paths.dataset, run_options.random_seed) 
    


    
    #for i in range(1,hyperp.num_networks):
    for i in range(1,2):
    #=== Initiate training ===#
        #trainer(hyperp, run_options, file_paths,i) 
        if i>1:
            trainable=2

    
            
        if trainable==2:
        
        
        
            #=== GPU Settings ===#
            os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
            os.environ["CUDA_VISIBLE_DEVICES"] = run_options.which_gpu
    
            #=== Neural Network ===#
            if run_options.use_L1 == 0:
                kernel_regularizer = None
                bias_regularizer = None  
            else:
                kernel_regularizer = tf.keras.regularizers.l1(hyperp.regularization)
                bias_regularizer = tf.keras.regularizers.l1(hyperp.regularization)
            
            
            multiply=0
        
            if multiply==0:

                data_train,new_label,labels_train=create_new(data_train, labels_train,hyperp,hyperp_new, run_options, data_input_shape, label_dimensions,i)
        
            if multiply==1:

                data_train,new_label,labels_train=create_new_multiply(data_train, labels_train,hyperp,hyperp_new, run_options, data_input_shape, label_dimensions,i)
     
        #=== Construct Validation Set and Batches ===# 
            data_and_labels_train, data_and_labels_val, data_and_labels_test,\
            num_data_train, num_data_val, num_data_test,\
            num_batches_train, num_batches_val, num_batches_test,data_and_labels_train_new\
            = form_train_val_test_batches(data_train, labels_train, \
                                      data_test, labels_test, \
                                      hyperp.batch_size, new_label, run_options.random_seed)
        
        
            # Creating validation data
            
            data_and_labels_val = tf.data.Dataset.from_tensor_slices((data_val, labels_val)).batch(hyperp.batch_size)
            num_data_val = len(list(data_and_labels_val))
            
    
        if i==1 and trainable==2:
            NN = FCLayerwise(hyperp, run_options, data_input_shape, label_dimensions,kernel_regularizer, bias_regularizer)    
            NN._set_inputs( data_train)
        if i>1:
            kernel_regularizer = None
            bias_regularizer = None
            NN = FCLayerwise_new(hyperp_new, run_options, data_input_shape, label_dimensions,kernel_regularizer, bias_regularizer) 
            NN._set_inputs( data_train)
    #=== Training ===#
    #                                 Training                                    #
###############################################################################
        if trainable>2:
            del NN
            NN = Final(hyperp, run_options, data_input_shape, label_dimensions,kernel_regularizer, bias_regularizer,trainable)   
            #NN._set_inputs(data_train)
            NN.load_weights("WEIGHTS"+'/'+"model_weights"+str(1)+str(trainable-1))
            #NN=tf.keras.models.load_model("WEIGHTS"+'/'+"model"+str(1)+str(trainable-1))
        


        if i==1:
            hyperp_n=hyperp
            optimize(hyperp,hyperp_n, run_options, file_paths, NN, data_loss_classification, data_loss_regression, data_and_labels_train, data_and_labels_val, data_and_labels_test, label_dimensions, num_batches_train,data_and_labels_train_new,manifold_classification,hyperp.batch_size,run_options.random_seed,num_data_train,i,data_input_shape,data_train,labels_train,multiply,trainable, labels_train_manifold, data_train_manifold)   
        
        if i>1:
            hyperp_n=Hyperparameters_new()
            optimize_step(hyperp,hyperp_n, run_options, file_paths, NN, data_loss_classification, data_loss_regression, data_and_labels_train, data_and_labels_val, data_and_labels_test, label_dimensions, num_batches_train,data_and_labels_train_new,manifold_classification_new,hyperp.batch_size,run_options.random_seed,num_data_train,i,data_input_shape,data_train,labels_train,multiply)   
        
        #NN.save("WEIGHTS"+'/'+"model"+str(1)+str(trainable))
        if not os.path.exists("WEIGHTS"):
            os.makedirs("WEIGHTS")
        NN.save_weights("WEIGHTS"+'/'+"model_weights"+str(1)+str(trainable))
        
       # if i==1:
          #  plot_fig(hyperp, run_options, file_paths,i,trainable+1)
            
      #  if i>1:
        #    plot_fig(hyperp_new, run_options, file_paths,i,3)
# Out:
# 2022-06-23 22:19:30.146313: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-23 22:19:30.179397: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2593830000 Hz
# 2022-06-23 22:19:30.181316: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e2a8975660 executing computations on platform Host. Devices:
# 2022-06-23 22:19:30.181356: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2022-06-23 22:19:30.183554: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# ListWrapper([10, 100, 100, 12])
# Beginning Training
# ================================
#             Epoch 0
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Model: "fc_layerwise"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# W2 (Dense)                   multiple                  10100
# _________________________________________________________________
# upsampling_layer (Dense)     multiple                  1100
# _________________________________________________________________
# classification_layer (Dense) multiple                  1212
# =================================================================
# Total params: 12,412
# Trainable params: 12,412
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Layer fc_layerwise is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# Time per Batch: 0.47
# Time per Epoch: 0.69
#
# Training Set: Loss: 9.785e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.957
# Test Set: Loss: 0.000e+00, Accuracy: 1.039
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 1
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.42
# Time per Epoch: 0.62
#
# Training Set: Loss: 9.265e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.946
# Test Set: Loss: 0.000e+00, Accuracy: 1.018
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 2
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.40
# Time per Epoch: 0.59
#
# Training Set: Loss: 9.064e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.950
# Test Set: Loss: 0.000e+00, Accuracy: 1.020
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 3
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.40
# Time per Epoch: 0.63
#
# Training Set: Loss: 9.026e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.935
# Test Set: Loss: 0.000e+00, Accuracy: 1.014
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 4
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.42
# Time per Epoch: 0.62
#
# Training Set: Loss: 9.034e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.46
# Time per Epoch: 0.69
#
# Training Set: Loss: 7.042e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.806
# Test Set: Loss: 0.000e+00, Accuracy: 0.860
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 92
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.46
# Time per Epoch: 0.69
#
# Training Set: Loss: 7.024e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.823
# Test Set: Loss: 0.000e+00, Accuracy: 0.887
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 93
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.44
# Time per Epoch: 0.64
#
# Training Set: Loss: 7.004e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.803
# Test Set: Loss: 0.000e+00, Accuracy: 0.860
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 94
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.40
# Time per Epoch: 0.59
#
# Training Set: Loss: 6.986e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.824
# Test Set: Loss: 0.000e+00, Accuracy: 0.883
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 95
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.40
# Time per Epoch: 0.60
#
# Training Set: Loss: 6.965e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.798
# Test Set: Loss: 0.000e+00, Accuracy: 0.859
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 96
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.40
# Time per Epoch: 0.59
#
# Training Set: Loss: 6.945e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.827
# Test Set: Loss: 0.000e+00, Accuracy: 0.880
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 97
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.40
# Time per Epoch: 0.60
#
# Training Set: Loss: 6.929e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.792
# Test Set: Loss: 0.000e+00, Accuracy: 0.857
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 98
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.40
# Time per Epoch: 0.60
#
# Training Set: Loss: 6.911e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.828
# Test Set: Loss: 0.000e+00, Accuracy: 0.878
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 99
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 2
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.40
# Time per Epoch: 0.59
#
# Training Set: Loss: 6.894e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.790
# Test Set: Loss: 0.000e+00, Accuracy: 0.856
#
# Previous Layer Relative # of 0s: 0.0000000
#
# ================================
#             Epoch 100
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# ...
# Validation Set: Loss: 0.000e+00, Accuracy: 0.612
# Test Set: Loss: 0.000e+00, Accuracy: 0.697
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 139
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.90
# Time per Epoch: 1.37
#
# Training Set: Loss: 2.026e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.609
# Test Set: Loss: 0.000e+00, Accuracy: 0.674
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 140
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.90
# Time per Epoch: 1.37
#
# Training Set: Loss: 2.035e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.612
# Test Set: Loss: 0.000e+00, Accuracy: 0.697
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 141
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.92
# Time per Epoch: 1.41
#
# Training Set: Loss: 2.026e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.609
# Test Set: Loss: 0.000e+00, Accuracy: 0.674
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 142
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.90
# Time per Epoch: 1.37
#
# Training Set: Loss: 2.034e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.612
# Test Set: Loss: 0.000e+00, Accuracy: 0.697
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 143
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.91
# Time per Epoch: 1.41
#
# Training Set: Loss: 2.025e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.609
# Test Set: Loss: 0.000e+00, Accuracy: 0.675
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 144
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.93
# Time per Epoch: 1.38
#
# Training Set: Loss: 2.034e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.612
# Test Set: Loss: 0.000e+00, Accuracy: 0.697
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 145
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 1.01
# Time per Epoch: 1.49
#
# Training Set: Loss: 2.025e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.609
# Test Set: Loss: 0.000e+00, Accuracy: 0.675
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 146
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.94
# Time per Epoch: 1.39
#
# Training Set: Loss: 2.033e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.612
# Test Set: Loss: 0.000e+00, Accuracy: 0.697
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 147
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.89
# Time per Epoch: 1.34
#
# Training Set: Loss: 2.025e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.609
# Test Set: Loss: 0.000e+00, Accuracy: 0.675
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 148
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.94
# Time per Epoch: 1.46
#
# Training Set: Loss: 2.033e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.612
# Test Set: Loss: 0.000e+00, Accuracy: 0.697
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 149
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.92
# Time per Epoch: 1.40
#
# Training Set: Loss: 2.024e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.609
# Test Set: Loss: 0.000e+00, Accuracy: 0.675
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 150
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.89
# Time per Epoch: 1.34
#
# Training Set: Loss: 2.033e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.612
# Test Set: Loss: 0.000e+00, Accuracy: 0.698
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 151
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.89
# Time per Epoch: 1.35
#
# Training Set: Loss: 2.024e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.610
# Test Set: Loss: 0.000e+00, Accuracy: 0.675
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 152
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.89
# Time per Epoch: 1.33
#
# Training Set: Loss: 2.032e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.612
# Test Set: Loss: 0.000e+00, Accuracy: 0.698
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 153
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 1.03
# Time per Epoch: 1.55
#
# Training Set: Loss: 2.024e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.610
# Test Set: Loss: 0.000e+00, Accuracy: 0.675
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 154
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.90
# Time per Epoch: 1.35
#
# Training Set: Loss: 2.032e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.612
# Test Set: Loss: 0.000e+00, Accuracy: 0.697
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 155
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.90
# Time per Epoch: 1.35
#
# Training Set: Loss: 2.024e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.610
# Test Set: Loss: 0.000e+00, Accuracy: 0.675
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 156
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.89
# Time per Epoch: 1.38
#
# Training Set: Loss: 2.032e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.612
# Test Set: Loss: 0.000e+00, Accuracy: 0.698
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 157
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.91
# Time per Epoch: 1.37
#
# Training Set: Loss: 2.023e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.610
# Test Set: Loss: 0.000e+00, Accuracy: 0.675
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 158
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.95
# Time per Epoch: 1.40
#
# Training Set: Loss: 2.032e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.612
# Test Set: Loss: 0.000e+00, Accuracy: 0.698
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 159
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.92
# Time per Epoch: 1.36
#
# Training Set: Loss: 2.023e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.611
# Test Set: Loss: 0.000e+00, Accuracy: 0.675
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 160
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.91
# Time per Epoch: 1.35
#
# Training Set: Loss: 2.031e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.612
# Test Set: Loss: 0.000e+00, Accuracy: 0.699
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 161
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.89
# Time per Epoch: 1.34
#
# Training Set: Loss: 2.023e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.611
# Test Set: Loss: 0.000e+00, Accuracy: 0.675
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 162
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.91
# Time per Epoch: 1.35
#
# Training Set: Loss: 2.031e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.612
# Test Set: Loss: 0.000e+00, Accuracy: 0.699
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 163
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# Time per Batch: 0.89
# Time per Epoch: 1.34
#
# Training Set: Loss: 2.022e-01, Accuracy: 0.000
# Validation Set: Loss: 0.000e+00, Accuracy: 0.611
# Test Set: Loss: 0.000e+00, Accuracy: 0.675
#
# Previous Layer Relative # of 0s: 0.6856436
#
# ================================
#             Epoch 164
# ================================
# Abalone_FC_L1_mhl15_hl100_rpt0001_nTOL4_eTOL4_b20_e400
# Trainable Hidden Layer Index: 8
# GPU: 1
#
# Optimizing 1 batches of size 20:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_21418/785762211.py in <module>
#      96         if i==1:
#      97             hyperp_n=hyperp
# ---> 98             optimize(hyperp,hyperp_n, run_options, file_paths, NN, data_loss_classification, data_loss_regression, data_and_labels_train, data_and_labels_val, data_and_labels_test, label_dimensions, num_batches_train,data_and_labels_train_new,manifold_classification,hyperp.batch_size,run_options.random_seed,num_data_train,i,data_input_shape,data_train,labels_train,multiply,trainable, labels_train_manifold, data_train_manifold)
#      99
#     100         if i>1:
#
# ~/Desktop/INVERSE_PROBLEM_TRIAL_2/Utilities/optimize_layerwise.py in optimize(hyperp, hyperp_new, run_options, file_paths, NN, data_loss, accuracy, data_and_labels_train, data_and_labels_val, data_and_labels_test, label_dimensions, num_batches_train, data_and_labels_train_new, manifold_class, batch_size, random_seed, num_data_train, i_val, data_input_shape, data_train, labels_train, multiply, trainable_hidden_layer_index, labels_train_manifold, data_train_manifold)
#     101                 with tf.GradientTape() as tape:
#     102                     start_time_batch = time.time()
# --> 103                     batch_pred_train,val = NN(batch_data_train)
#     104                     #=== Display Model Summary ===#
#     105                     if batch_num == 0 and epoch == 0:
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/Desktop/INVERSE_PROBLEM_TRIAL_2/Utilities/NN_FC_layerwise.py in call(self, inputs)
#      87 ###############################################################################
#      88 #                                 Add Layer                                   #
# ---> 89 ###############################################################################
#      90     def add_layer(self, trainable_hidden_layer_index, freeze=True ,add = True):
#      91         #kernel_initializer = RandomNormal(mean=0.0, stddev=0.005)
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/layers/core.py in call(self, inputs)
#    1058       outputs = nn.bias_add(outputs, self.bias)
#    1059     if self.activation is not None:
# -> 1060       return self.activation(outputs)  # pylint: disable=not-callable
#    1061     return outputs
#    1062
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/activations.py in elu(x, alpha)
#      89         Linear Units (ELUs)](https://arxiv.org/abs/1511.07289)
#      90   """
# ---> 91   return K.elu(x, alpha)
#      92
#      93
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in elu(x, alpha)
#    4375       A tensor.
#    4376   """
# -> 4377   res = nn.elu(x)
#    4378   if alpha == 1:
#    4379     return res
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_nn_ops.py in elu(features, name)
#    3168       _result = _pywrap_tensorflow.TFE_Py_FastPathExecute(
#    3169         _ctx._context_handle, _ctx._thread_local_data.device_name, "Elu",
# -> 3170         name, _ctx._post_execution_callbacks, features)
#    3171       return _result
#    3172     except _core._FallbackException:
#
# KeyboardInterrupt:
