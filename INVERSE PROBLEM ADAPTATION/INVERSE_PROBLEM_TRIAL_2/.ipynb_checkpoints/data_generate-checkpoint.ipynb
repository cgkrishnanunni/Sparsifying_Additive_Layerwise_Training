# %%
import sklearn.model_selection as sk
from sklearn.datasets import load_boston
from sklearn.datasets import make_regression
from sklearn.datasets import make_friedman1
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing 
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot

# %%
data_train=pd.read_csv("data_train.csv")
labels_train=pd.read_csv("labels_train.csv")
data_test=pd.read_csv("data_test.csv")
labels_test=pd.read_csv("labels_test.csv")
data_train_no_noise=pd.read_csv("data_train_no_noise.csv")

# %%
       
data_train=np.array(data_train)
labels_train=np.array(labels_train)
data_test=np.array(data_test)
labels_test=np.array(labels_test)
data_train_no_noise=np.array(data_train_no_noise)

data_train=np.reshape(data_train,(10000,10))
labels_train=np.reshape(labels_train,(10000,12))
data_test=np.reshape(data_test,(500,10))
labels_test=np.reshape(labels_test,(500,12))
data_train_no_noise=np.reshape(data_train_no_noise,(10000,10))

for i in range(0,10000):

   # data_train[i]=data_train_no_noise[i]+(np.random.rand()/10)*np.std(data_train_no_noise[i])*np.random.randn(len(data_train_no_noise[i]))
     data_train[i]=data_train_no_noise[i]+0.05*np.std(data_train_no_noise[i])*np.random.randn(len(data_train_no_noise[i]))

# %%
data_val=data_train[60:80]
labels_val=labels_train[60:80]

data_train=data_train[0:50]
labels_train=labels_train[0:50]

# %%
# Creating data for manifold regularization
data_train_manifold=[]
labels_train_manifold=[]

no=40

for j in range(0,50):
    
    
    data_train_new=np.zeros((no,10))
    labels_train_new=np.zeros((no,))
    for i in range(0,no):

        data_train_new[i]=data_train[j]+np.std(data_train[j])*(0.01)*np.random.randn(len(data_train[j]))
    
        labels_train_new[i]=j
        
    if j==0:
        data_train_manifold=data_train_new
        labels_train_manifold=labels_train_new
        
        
    if j!=0:    
       
        data_train_manifold=np.append(data_train_manifold,data_train_new,axis=0)
        labels_train_manifold=np.append(labels_train_manifold,labels_train_new,axis=0)
    
    
    
#x_train_new = batch_data_train[batch_labels_train == i]

# %%
data_test = tf.cast(data_test, tf.float32)
labels_test = tf.cast(labels_test, tf.float32)
data_train = tf.cast(data_train, tf.float32)
labels_train = tf.cast(labels_train, tf.float32)
data_val=tf.cast(data_val, tf.float32)
labels_val=tf.cast(labels_val, tf.float32)



data_train_manifold=tf.cast(data_train_manifold, tf.float32)
labels_train_manifold=tf.cast(labels_train_manifold, tf.int32)

# %%
np.savetxt("data_train.data", data_train)
np.savetxt("data_test.data", data_test)
np.savetxt("labels_test.data", labels_test)
np.savetxt("labels_train.data", labels_train)
np.savetxt("labels_val.data", labels_val)
np.savetxt("data_val.data", data_val)

np.savetxt("data_train_manifold.data", data_train_manifold)

np.savetxt("labels_train_manifold.data", labels_train_manifold)

# %%
data_train_manifold

# %%
#from sklearn.utils import shuffle
#data_train_cluster, labels_train_cluster = shuffle(data_train_cluster, labels_train_cluster)

# %%
data_train=np.loadtxt("data_train.data")
labels_train=np.loadtxt("labels_train.data")
data_test=np.loadtxt("data_test.data")
labels_test=np.loadtxt("labels_test.data")
        


x_train=data_train
y_train=labels_train


x_test=data_test
y_test=labels_test

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras import regularizers

val=[]

for i in range(0,100):
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=200,restore_best_weights=True)


    model = keras.Sequential()
    model.add(layers.Dense(100,  activation='linear', input_shape=(10,)))
    model.add(layers.Dense(100,  activation='elu'))
    model.add(layers.Dense(100,  activation='elu'))
    model.add(layers.Dense(100,  activation='elu'))
    model.add(layers.Dense(100,  activation='elu'))
    model.add(layers.Dense(100,  activation='elu'))
    model.add(layers.Dense(100,  activation='elu'))
    model.add(layers.Dense(100,  activation='elu'))
    model.add(layers.Dense(100,  activation='elu'))
    model.add(layers.Dense(12, activation='linear'))
    model.summary()





    opt = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mean_squared_error'])
    history=model.fit(x_train,y_train,batch_size=50,epochs=3000,validation_data=[x_test, y_test],callbacks=[callback],verbose=1)
    plt.plot(history.history['val_mean_squared_error'])
    plt.show()
    val=np.append(val,model.evaluate(x_test, y_test)[0])
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_223 (Dense)            (None, 100)               1100
# _________________________________________________________________
# dense_224 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_225 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_226 (Dense)            (None, 12)                1212
# =================================================================
# Total params: 22,512
# Trainable params: 22,512
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50 samples, validate on 500 samples
# Epoch 1/3000
# 50/50 [==============================] - 1s 21ms/sample - loss: 1.1314 - mean_squared_error: 1.1314 - val_loss: 1.0244 - val_mean_squared_error: 1.0244
# Epoch 2/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.9759 - mean_squared_error: 0.9759 - val_loss: 1.0256 - val_mean_squared_error: 1.0256
# Epoch 3/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.9675 - mean_squared_error: 0.9675 - val_loss: 1.0546 - val_mean_squared_error: 1.0546
# Epoch 4/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.9879 - mean_squared_error: 0.9879 - val_loss: 1.0623 - val_mean_squared_error: 1.0623
# Epoch 5/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.9891 - mean_squared_error: 0.9891 - val_loss: 1.0471 - val_mean_squared_error: 1.0471
# Epoch 6/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.9697 - mean_squared_error: 0.9697 - val_loss: 1.0223 - val_mean_squared_error: 1.0223
# Epoch 7/3000
# 50/50 [==============================] - 0s 4ms/sample - loss: 0.9434 - mean_squared_error: 0.9434 - val_loss: 0.9992 - val_mean_squared_error: 0.9992
# Epoch 8/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.9214 - mean_squared_error: 0.9214 - val_loss: 0.9828 - val_mean_squared_error: 0.9828
# Epoch 9/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.9084 - mean_squared_error: 0.9084 - val_loss: 0.9735 - val_mean_squared_error: 0.9735
# Epoch 10/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.9040 - mean_squared_error: 0.9040 - val_loss: 0.9681 - val_mean_squared_error: 0.9681
# Epoch 11/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.9036 - mean_squared_error: 0.9036 - val_loss: 0.9626 - val_mean_squared_error: 0.9626
# Epoch 12/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.9016 - mean_squared_error: 0.9016 - val_loss: 0.9547 - val_mean_squared_error: 0.9547
# Epoch 13/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.8946 - mean_squared_error: 0.8946 - val_loss: 0.9447 - val_mean_squared_error: 0.9447
# Epoch 14/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.8830 - mean_squared_error: 0.8830 - val_loss: 0.9352 - val_mean_squared_error: 0.9352
# Epoch 15/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.8695 - mean_squared_error: 0.8695 - val_loss: 0.9282 - val_mean_squared_error: 0.9282
# Epoch 16/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.8572 - mean_squared_error: 0.8572 - val_loss: 0.9241 - val_mean_squared_error: 0.9241
# Epoch 17/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.8474 - mean_squared_error: 0.8474 - val_loss: 0.9219 - val_mean_squared_error: 0.9219
# Epoch 18/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.8401 - mean_squared_error: 0.8401 - val_loss: 0.9200 - val_mean_squared_error: 0.9200
# Epoch 19/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.8342 - mean_squared_error: 0.8342 - val_loss: 0.9175 - val_mean_squared_error: 0.9175
# Epoch 20/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.8288 - mean_squared_error: 0.8288 - val_loss: 0.9134 - val_mean_squared_error: 0.9134
# Epoch 21/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.8226 - mean_squared_error: 0.8226 - val_loss: 0.9075 - val_mean_squared_error: 0.9075
# Epoch 22/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.8152 - mean_squared_error: 0.8152 - val_loss: 0.8998 - val_mean_squared_error: 0.8998
# Epoch 23/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.8064 - mean_squared_error: 0.8064 - val_loss: 0.8911 - val_mean_squared_error: 0.8911
# Epoch 24/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.
3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2984 - mean_squared_error: 0.2984 - val_loss: 0.4536 - val_mean_squared_error: 0.4536
# Epoch 220/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2995 - mean_squared_error: 0.2995 - val_loss: 0.4603 - val_mean_squared_error: 0.4603
# Epoch 221/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2973 - mean_squared_error: 0.2973 - val_loss: 0.4522 - val_mean_squared_error: 0.4522
# Epoch 222/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2944 - mean_squared_error: 0.2944 - val_loss: 0.4508 - val_mean_squared_error: 0.4508
# Epoch 223/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2949 - mean_squared_error: 0.2949 - val_loss: 0.4588 - val_mean_squared_error: 0.4588
# Epoch 224/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2955 - mean_squared_error: 0.2955 - val_loss: 0.4504 - val_mean_squared_error: 0.4504
# Epoch 225/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2936 - mean_squared_error: 0.2936 - val_loss: 0.4484 - val_mean_squared_error: 0.4484
# Epoch 226/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2920 - mean_squared_error: 0.2920 - val_loss: 0.4581 - val_mean_squared_error: 0.4581
# Epoch 227/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2924 - mean_squared_error: 0.2924 - val_loss: 0.4430 - val_mean_squared_error: 0.4430
# Epoch 228/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2921 - mean_squared_error: 0.2921 - val_loss: 0.4588 - val_mean_squared_error: 0.4588
# Epoch 229/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2919 - mean_squared_error: 0.2919 - val_loss: 0.4454 - val_mean_squared_error: 0.4454
# Epoch 230/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2953 - mean_squared_error: 0.2953 - val_loss: 0.4769 - val_mean_squared_error: 0.4769
# Epoch 231/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.3037 - mean_squared_error: 0.3037 - val_loss: 0.4495 - val_mean_squared_error: 0.4495
# Epoch 232/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.3122 - mean_squared_error: 0.3122 - val_loss: 0.4909 - val_mean_squared_error: 0.4909
# Epoch 233/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.3081 - mean_squared_error: 0.3081 - val_loss: 0.4373 - val_mean_squared_error: 0.4373
# Epoch 234/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2913 - mean_squared_error: 0.2913 - val_loss: 0.4434 - val_mean_squared_error: 0.4434
# Epoch 235/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2899 - mean_squared_error: 0.2899 - val_loss: 0.4798 - val_mean_squared_error: 0.4798
# Epoch 236/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.3004 - mean_squared_error: 0.3004 - val_loss: 0.4354 - val_mean_squared_error: 0.4354
# Epoch 237/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2943 - mean_squared_error: 0.2943 - val_loss: 0.4455 - val_mean_squared_error: 0.4455
# Epoch 238/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2849 - mean_squared_error: 0.2849 - val_loss: 0.4675 - val_mean_squared_error: 0.4675
# Epoch 239/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2923 - mean_squared_error: 0.2923 - val_loss: 0.4346 - val_mean_squared_error: 0.4346
# Epoch 240/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2921 - mean_squared_error: 0.2921 - val_loss: 0.4455 - val_mean_squared_error: 0.4455
# Epoch 241/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2831 - mean_squared_error: 0.2831 - val_loss: 0.4602 - val_mean_squared_error: 0.4602
# Epoch 242/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2876 - mean_squared_error: 0.2876 - val_loss: 0.4337 - val_mean_squared_error: 0.4337
# Epoch 243/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2888 - mean_squared_error: 0.2888 - val_loss: 0.4442 - val_mean_squared_error: 0.4442
# Epoch 244/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2817 - mean_squared_error: 0.2817 - val_loss: 0.4556 - val_mean_squared_error: 0.4556
# Epoch 245/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2845 - mean_squared_error: 0.2845 - val_loss: 0.4329 - val_mean_squared_error: 0.4329
# Epoch 246/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2856 - mean_squared_error: 0.2856 - val_loss: 0.4427 - val_mean_squared_error: 0.4427
# Epoch 247/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2807 - mean_squared_error: 0.2807 - val_loss: 0.4517 - val_mean_squared_error: 0.4517
# Epoch 248/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.
3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2796 - mean_squared_error: 0.2796 - val_loss: 0.4361 - val_mean_squared_error: 0.4361
# Epoch 278/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2699 - mean_squared_error: 0.2699 - val_loss: 0.4409 - val_mean_squared_error: 0.4409
# Epoch 279/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2739 - mean_squared_error: 0.2739 - val_loss: 0.4367 - val_mean_squared_error: 0.4367
# Epoch 280/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2770 - mean_squared_error: 0.2770 - val_loss: 0.4362 - val_mean_squared_error: 0.4362
# Epoch 281/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2700 - mean_squared_error: 0.2700 - val_loss: 0.4342 - val_mean_squared_error: 0.4342
# Epoch 282/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2706 - mean_squared_error: 0.2706 - val_loss: 0.4396 - val_mean_squared_error: 0.4396
# Epoch 283/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2744 - mean_squared_error: 0.2744 - val_loss: 0.4318 - val_mean_squared_error: 0.4318
# Epoch 284/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2694 - mean_squared_error: 0.2694 - val_loss: 0.4337 - val_mean_squared_error: 0.4337
# Epoch 285/3000
# ...
# Epoch 274/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2648 - mean_squared_error: 0.2648 - val_loss: 0.4280 - val_mean_squared_error: 0.4280
# Epoch 275/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2695 - mean_squared_error: 0.2695 - val_loss: 0.4296 - val_mean_squared_error: 0.4296
# Epoch 276/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2644 - mean_squared_error: 0.2644 - val_loss: 0.4285 - val_mean_squared_error: 0.4285
# Epoch 277/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2622 - mean_squared_error: 0.2622 - val_loss: 0.4267 - val_mean_squared_error: 0.4267
# Epoch 278/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2667 - mean_squared_error: 0.2667 - val_loss: 0.4328 - val_mean_squared_error: 0.4328
# Epoch 279/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2639 - mean_squared_error: 0.2639 - val_loss: 0.4231 - val_mean_squared_error: 0.4231
# Epoch 280/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2615 - mean_squared_error: 0.2615 - val_loss: 0.4285 - val_mean_squared_error: 0.4285
# Epoch 281/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2642 - mean_squared_error: 0.2642 - val_loss: 0.4305 - val_mean_squared_error: 0.4305
# Epoch 282/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2626 - mean_squared_error: 0.2626 - val_loss: 0.4209 - val_mean_squared_error: 0.4209
# Epoch 283/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2611 - mean_squared_error: 0.2611 - val_loss: 0.4316 - val_mean_squared_error: 0.4316
# Epoch 284/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2628 - mean_squared_error: 0.2628 - val_loss: 0.4262 - val_mean_squared_error: 0.4262
# Epoch 285/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2612 - mean_squared_error: 0.2612 - val_loss: 0.4214 - val_mean_squared_error: 0.4214
# Epoch 286/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2601 - mean_squared_error: 0.2601 - val_loss: 0.4323 - val_mean_squared_error: 0.4323
# Epoch 287/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2617 - mean_squared_error: 0.2617 - val_loss: 0.4226 - val_mean_squared_error: 0.4226
# Epoch 288/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2605 - mean_squared_error: 0.2605 - val_loss: 0.4238 - val_mean_squared_error: 0.4238
# Epoch 289/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2591 - mean_squared_error: 0.2591 - val_loss: 0.4300 - val_mean_squared_error: 0.4300
# Epoch 290/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2603 - mean_squared_error: 0.2603 - val_loss: 0.4216 - val_mean_squared_error: 0.4216
# Epoch 291/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2599 - mean_squared_error: 0.2599 - val_loss: 0.4262 - val_mean_squared_error: 0.4262
# Epoch 292/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.2586 - mean_squared_error: 0.2586 - val_loss: 0.4263 - val_mean_squared_error: 0.4263
# Epoch 293/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2591 - mean_squared_error: 0.2591 - val_loss: 0.4229 - val_mean_squared_error: 0.4229
# Epoch 294/3000
# 50/50 [==============================] - 0s 3ms/sample - loss: 0.
3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2533 - mean_squared_error: 0.2533 - val_loss: 0.4243 - val_mean_squared_error: 0.4243
# Epoch 322/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2531 - mean_squared_error: 0.2531 - val_loss: 0.4225 - val_mean_squared_error: 0.4225
# Epoch 323/3000
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2529 - mean_squared_error: 0.2529 - val_loss: 0.4227 - val_mean_squared_error: 0.4227
# Epoch 324/3000
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 50/50 [==============================] - 0s 2ms/sample - loss: 0.2527 - mean_squared_error: 0.2527
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_27968/1384629407.py in <module>
#      25     opt = keras.optimizers.Adam(learning_rate=0.001)
#      26     model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mean_squared_error'])
# ---> 27     history=model.fit(x_train,y_train,batch_size=50,epochs=3000,validation_data=[x_test, y_test],callbacks=[callback],verbose=1)
#      28     plt.plot(history.history['val_mean_squared_error'])
#      29     plt.show()
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     368                       mode=ModeKeys.TEST,
#     369                       training_context=eval_context,
# --> 370                       total_epochs=1)
#     371                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
#     372                                  prefix='val_')
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     492       # In this case we have not created variables on the first call. So we can
#     493       # run the first trace but we should fail if variables are created.
# --> 494       results = self._stateful_fn(*args, **kwds)
#     495       if self._created_variables:
#     496         raise ValueError("Creating variables on a non-first call to a function"
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1235     tape.record_operation(forward_function.signature.name,
#    1236                           to_record, args, backward_function)
# -> 1237     return self._build_call_outputs(flat_outputs)
#    1238
#    1239   def _experimental_with_cancellation_manager(self, cancellation_manager):
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _build_call_outputs(self, result)
#    1413         j += 1
#    1414     ret = nest.pack_sequence_as(self._func_graph.structured_outputs,
# -> 1415                                 outputs_list, expand_composites=True)
#    1416     return ret
#    1417
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/util/nest.py in pack_sequence_as(structure, flat_sequence, expand_composites)
#     459   try:
#     460     final_index, packed = _packed_nest_with_indices(structure, flat_sequence,
# --> 461                                                     0, is_seq)
#     462     if final_index < len(flat_sequence):
#     463       raise IndexError
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/util/nest.py in _packed_nest_with_indices(structure, flat, index, is_seq)
#     405   for s in _yield_value(structure):
#     406     if is_seq(s):
# --> 407       new_index, child = _packed_nest_with_indices(s, flat, index, is_seq)
#     408       packed.append(_sequence_like(s, child))
#     409       index = new_index
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/util/nest.py in _packed_nest_with_indices(structure, flat, index, is_seq)
#     403   """
#     404   packed = []
# --> 405   for s in _yield_value(structure):
#     406     if is_seq(s):
#     407       new_index, child = _packed_nest_with_indices(s, flat, index, is_seq)
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/util/nest.py in _yield_value(iterable)
#     163
#     164 def _yield_value(iterable):
# --> 165   for _, v in _yield_sorted_items(iterable):
#     166     yield v
#     167
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/util/nest.py in _yield_sorted_items(iterable)
#     190     for key in _sorted(iterable):
#     191       yield key, iterable[key]
# --> 192   elif _is_attrs(iterable):
#     193     for item in _get_attrs_items(iterable):
#     194       yield item
#
# /workspace/krish/anaconda/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/pywrap_tensorflow_internal.py in IsAttrs(o)
#    2584     return _pywrap_tensorflow_internal.IsMappingView(o)
#    2585
# -> 2586 def IsAttrs(o):
#    2587     """
#    2588     Returns True iff `instance` is an instance of an `attr.s` decorated class.
#
# KeyboardInterrupt:

# %%
val=val*100

# %%
np.mean(val)
# Out:
# 41.82014546990395

# %%
np.std(val)
# Out:
# 1.8685578330633275
